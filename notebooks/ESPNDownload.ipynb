# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

from os.path import join
from webUtils import getWebData, getHTML, removeTag
from fsUtils import isFile
from searchUtils import findExt

## Python Version
import sys
print("Python: {0}".format(sys.version))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
baseURL  = "https://www.cbssports.com"
CBSURL   = join(baseURL, "college-football")
savename = "data/cbs.p"
    
retval = getWebData(base=CBSURL, savename=savename, useSafari=False)
# Out:
#   --> This file is 63.7kB.
# data/cbs.p size -> 64 kB

# %%
standingsURL   = join(CBSURL, "standings")
savename = "data/cbs_standings.p"

retval = getWebData(base=standingsURL, savename=savename, useSafari=False)
# Out:
#   --> This file is 95.2kB.
# data/cbs_standings.p size -> 95 kB

# %%
bs    = getHTML(savename)
spans = bs.findAll("span", {"class": "CellLogoNameLockup"})

# %%
from time import sleep
for span in spans:
    refs = span.findAll("a")
    if len(refs) == 2:
        teamName = refs[1].text
        teamURL  = refs[1].attrs['href']
        
        url = "{0}{1}".format(baseURL,teamURL)
        savename = "data/teams/{0}.p".format(teamName)

        if not isFile(savename):
            retval = getWebData(base=url, savename=savename, useSafari=False)
            sleep(1.5)
# Out:
#   --> This file is 80.1kB.
# data/teams/Temple.p size -> 80 kB
#   --> This file is 79.3kB.
# data/teams/South Florida.p size -> 79 kB
#   --> This file is 79.5kB.
# data/teams/East Carolina.p size -> 79 kB
#   --> This file is 78.4kB.
# data/teams/Connecticut.p size -> 78 kB
#   --> This file is 80.4kB.
# data/teams/SMU.p size -> 80 kB
#   --> This file is 80.8kB.
# data/teams/Navy.p size -> 81 kB
#   --> This file is 80.1kB.
# data/teams/Memphis.p size -> 80 kB
#   --> This file is 79.6kB.
# data/teams/Tulane.p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/Houston.p size -> 80 kB
#   --> This file is 78.7kB.
# data/teams/Tulsa.p size -> 79 kB
#   --> This file is 80.1kB.
# data/teams/Clemson.p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Wake Forest.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Louisville.p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Boston College.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Florida St..p size -> 80 kB
#   --> This file is 79.6kB.
# data/teams/NC State.p size -> 80 kB
#   --> This file is 79.9kB.
# data/teams/Syracuse.p size -> 80 kB
#   --> This file is 80.7kB.
# data/teams/Virginia.p size -> 81 kB
#   --> This file is 79.7kB.
# data/teams/Pittsburgh.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Duke.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Virginia Tech.p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/North Carolina.p size -> 80 kB
#   --> This file is 79.6kB.
# data/teams/Georgia Tech.p size -> 80 kB
#   --> This file is 79.9kB.
# data/teams/Miami (Fla.).p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Ohio St..p size -> 80 kB
#   --> This file is 80.5kB.
# data/teams/Penn St..p size -> 80 kB
#   --> This file is 80.5kB.
# data/teams/Michigan.p size -> 81 kB
#   --> This file is 79.7kB.
# data/teams/Indiana.p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/Michigan St..p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Maryland.p size -> 80 kB
#   --> This file is 80.0kB.
# data/teams/Rutgers.p size -> 80 kB
#   --> This file is 80.3kB.
# data/teams/Minnesota.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Wisconsin.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Iowa.p size -> 80 kB
#   --> This file is 80.6kB.
# data/teams/Nebraska.p size -> 81 kB
#   --> This file is 79.9kB.
# data/teams/Illinois.p size -> 80 kB
#   --> This file is 79.5kB.
# data/teams/Purdue.p size -> 79 kB
#   --> This file is 79.7kB.
# data/teams/Northwestern.p size -> 80 kB
#   --> This file is 80.5kB.
# data/teams/Oklahoma.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Baylor.p size -> 80 kB
#   --> This file is 80.3kB.
# data/teams/Texas.p size -> 80 kB
#   --> This file is 80.5kB.
# data/teams/Iowa St..p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Kansas St..p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/TCU.p size -> 80 kB
#   --> This file is 80.0kB.
# data/teams/Oklahoma St..p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Texas Tech.p size -> 80 kB
#   --> This file is 79.6kB.
# data/teams/West Virginia.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Kansas.p size -> 80 kB
#   --> This file is 79.2kB.
# data/teams/W. Kentucky.p size -> 79 kB
#   --> This file is 79.4kB.
# data/teams/Marshall.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/FAU.p size -> 80 kB
#   --> This file is 79.3kB.
# data/teams/FIU.p size -> 79 kB
#   --> This file is 79.0kB.
# data/teams/Middle Tenn..p size -> 79 kB
#   --> This file is 79.4kB.
# data/teams/Charlotte.p size -> 79 kB
#   --> This file is 79.0kB.
# data/teams/Old Dominion.p size -> 79 kB
#   --> This file is 79.4kB.
# data/teams/Louisiana Tech.p size -> 79 kB
#   --> This file is 79.5kB.
# data/teams/UAB.p size -> 80 kB
#   --> This file is 79.5kB.
# data/teams/So. Miss.p size -> 79 kB
#   --> This file is 79.5kB.
# data/teams/North Texas.p size -> 80 kB
#   --> This file is 78.9kB.
# data/teams/UT-San Antonio.p size -> 79 kB
#   --> This file is 79.0kB.
# data/teams/UTEP.p size -> 79 kB
#   --> This file is 79.0kB.
# data/teams/Rice.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Notre Dame.p size -> 80 kB
#   --> This file is 79.5kB.
# data/teams/Liberty.p size -> 80 kB
#   --> This file is 81.1kB.
# data/teams/Army.p size -> 81 kB
#   --> This file is 79.8kB.
# data/teams/BYU.p size -> 80 kB
#   --> This file is 78.7kB.
# data/teams/Massachusetts.p size -> 79 kB
#   --> This file is 78.8kB.
# data/teams/New Mexico St..p size -> 79 kB
#   --> This file is 79.7kB.
# data/teams/Kent St..p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Ohio.p size -> 80 kB
#   --> This file is 78.6kB.
# data/teams/Miami (Ohio).p size -> 79 kB
#   --> This file is 79.2kB.
# data/teams/Buffalo.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Bowling Green.p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Akron.p size -> 80 kB
#   --> This file is 78.9kB.
# data/teams/Ball St..p size -> 79 kB
#   --> This file is 79.9kB.
# data/teams/C. Michigan.p size -> 80 kB
#   --> This file is 78.8kB.
# data/teams/W. Michigan.p size -> 79 kB
#   --> This file is 79.3kB.
# data/teams/E. Michigan.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Toledo.p size -> 80 kB
#   --> This file is 78.9kB.
# data/teams/N. Illinois.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Boise St..p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Utah St..p size -> 80 kB
#   --> This file is 79.0kB.
# data/teams/Air Force.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Wyoming.p size -> 80 kB
#   --> This file is 79.6kB.
# data/teams/Colorado St..p size -> 80 kB
#   --> This file is 79.2kB.
# data/teams/New Mexico.p size -> 79 kB
#   --> This file is 79.3kB.
# data/teams/San Diego St..p size -> 79 kB
#   --> This file is 80.4kB.
# data/teams/Fresno St..p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Hawaii.p size -> 80 kB
#   --> This file is 80.0kB.
# data/teams/Nevada.p size -> 80 kB
#   --> This file is 80.0kB.
# data/teams/San Jose St..p size -> 80 kB
#   --> This file is 79.4kB.
# data/teams/UNLV.p size -> 79 kB
#   --> This file is 79.9kB.
# data/teams/Oregon.p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/Oregon St..p size -> 80 kB
#   --> This file is 79.4kB.
# data/teams/Stanford.p size -> 79 kB
#   --> This file is 79.7kB.
# data/teams/Washington.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Washington St..p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/California.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/USC.p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Utah.p size -> 80 kB
#   --> This file is 79.5kB.
# data/teams/Arizona.p size -> 79 kB
#   --> This file is 79.7kB.
# data/teams/Arizona St..p size -> 80 kB
#   --> This file is 79.9kB.
# data/teams/UCLA.p size -> 80 kB
#   --> This file is 80.3kB.
# data/teams/Colorado.p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Florida.p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Georgia.p size -> 80 kB
#   --> This file is 80.1kB.
# data/teams/Missouri.p size -> 80 kB
#   --> This file is 79.9kB.
# data/teams/South Carolina.p size -> 80 kB
#   --> This file is 79.3kB.
# data/teams/Vanderbilt.p size -> 79 kB
#   --> This file is 80.1kB.
# data/teams/Tennessee.p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Kentucky.p size -> 80 kB
#   --> This file is 80.5kB.
# data/teams/Alabama.p size -> 81 kB
#   --> This file is 80.1kB.
# data/teams/LSU.p size -> 80 kB
#   --> This file is 80.4kB.
# data/teams/Auburn.p size -> 80 kB
#   --> This file is 80.3kB.
# data/teams/Texas A&M.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Ole Miss.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/Miss. State.p size -> 80 kB
#   --> This file is 80.2kB.
# data/teams/Arkansas.p size -> 80 kB
#   --> This file is 79.8kB.
# data/teams/App. St..p size -> 80 kB
#   --> This file is 79.2kB.
# data/teams/Georgia St..p size -> 79 kB
#   --> This file is 79.9kB.
# data/teams/Ga. Southern.p size -> 80 kB
#   --> This file is 79.7kB.
# data/teams/Troy.p size -> 80 kB
#   --> This file is 79.1kB.
# data/teams/Coastal Carolina.p size -> 79 kB
#   --> This file is 79.6kB.
# data/teams/Louisiana.p size -> 80 kB
#   --> This file is 78.7kB.
# data/teams/UL-Monroe.p size -> 79 kB
#   --> This file is 79.2kB.
# data/teams/Texas St..p size -> 79 kB
#   --> This file is 79.3kB.
# data/teams/Arkansas St..p size -> 79 kB
#   --> This file is 79.5kB.
# data/teams/South Alabama.p size -> 80 kB

# %%
from fileUtils import getDirname, getBaseFilename, getBasename

files = findExt("data/teams", ".p")
for ifile in files:
    bsdata = getHTML(ifile)
    divs   = bsdata.findAll("div", {"class": "CellGame"})
    for div in divs:
        ref = div.find('a')
        if ref is not None:
            href = ref.attrs['href']
            if "gametracker" in href:
                print(href)
                url  = "{0}{1}".format(baseURL,href)                                
                gameName = href.split("/recap/")[-1][:-1]
                gameName = gameName.replace("@", "_")
                savename = "data/games/{0}.p".format(gameName)
                if not isFile(savename):
                    try:
                        retval = getWebData(base=url, savename=savename, useSafari=False)
                    except:
                        continue
                    sleep(1.5)
# Out:
# /college-football/gametracker/recap/NCAAF_20190830_TULSA@MICHST/
# /college-football/gametracker/recap/NCAAF_20190907_TULSA@SJST/
# /college-football/gametracker/recap/NCAAF_20190914_OKLAST@TULSA/
# /college-football/gametracker/recap/NCAAF_20190921_WYO@TULSA/
# /college-football/gametracker/recap/NCAAF_20191005_TULSA@SMU/
# /college-football/gametracker/recap/NCAAF_20191012_NAVY@TULSA/
# /college-football/gametracker/recap/NCAAF_20191019_TULSA@CINCY/
# /college-football/gametracker/recap/NCAAF_20190901_HOU@OKLA/
# /college-football/gametracker/recap/NCAAF_20190907_SD@OKLA/
# /college-football/gametracker/recap/NCAAF_20190914_OKLA@UCLA/
# /college-football/gametracker/recap/NCAAF_20190928_TXTECH@OKLA/
# /college-football/gametracker/recap/NCAAF_20191005_OKLA@KANSAS/
# /college-football/gametracker/recap/NCAAF_20191012_OKLA@TEXAS/
# /college-football/gametracker/recap/NCAAF_20191019_WVU@OKLA/
# /college-football/gametracker/recap/NCAAF_20190831_SC@UNC/
# /college-football/gametracker/recap/NCAAF_20190907_CHARSO@SC/
# /college-football/gametracker/recap/NCAAF_20190914_BAMA@SC/
# /college-football/gametracker/recap/NCAAF_20190921_SC@MIZZOU/
# /college-football/gametracker/recap/NCAAF_20190928_UK@SC/
# /college-football/gametracker/recap/NCAAF_20191012_SC@UGA/
# /college-football/gametracker/recap/NCAAF_20191019_FLA@SC/
# /college-football/gametracker/recap/NCAAF_20190829_WAG@UCONN/
# /college-football/gametracker/recap/NCAAF_20190907_ILL@UCONN/
# /college-football/gametracker/recap/NCAAF_20190921_UCONN@IND/
# /college-football/gametracker/recap/NCAAF_20190928_UCONN@UCF/
# /college-football/gametracker/recap/NCAAF_20191005_SFLA@UCONN/
# /college-football/gametracker/recap/NCAAF_20191012_UCONN@TULANE/
# /college-football/gametracker/recap/NCAAF_20191019_HOU@UCONN/
# /college-football/gametracker/recap/NCAAF_20190831_INST@KANSAS/
# /college-football/gametracker/recap/NCAAF_20190907_CSTCAR@KANSAS/
# /college-football/gametracker/recap/NCAAF_20190913_KANSAS@BC/
# /college-football/gametracker/recap/NCAAF_20190921_WVU@KANSAS/
# /college-football/gametracker/recap/NCAAF_20190928_KANSAS@TCU/
# /college-football/gametracker/recap/NCAAF_20191005_OKLA@KANSAS/
# /college-football/gametracker/recap/NCAAF_20191019_KANSAS@TEXAS/
# /college-football/gametracker/recap/NCAAF_20190831_MTSU@MICH/
# /college-football/gametracker/recap/NCAAF_20190907_TNST@MTSU/
# /college-football/gametracker/recap/NCAAF_20190914_DUKE@MTSU/
#   --> This file is 104.8kB.
# data/games/NCAAF_20190914_DUKE_MTSU.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190928_MTSU@IOWA/
#   --> This file is 108.0kB.
# data/games/NCAAF_20190928_MTSU_IOWA.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191005_MRSHL@MTSU/
#   --> This file is 104.3kB.
# data/games/NCAAF_20191005_MRSHL_MTSU.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191012_MTSU@FAU/
#   --> This file is 105.8kB.
# data/games/NCAAF_20191012_MTSU_FAU.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191019_MTSU@NTEXAS/
#   --> This file is 108.2kB.
# data/games/NCAAF_20191019_MTSU_NTEXAS.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190830_UTAHST@WAKE/
#   --> This file is 113.3kB.
# data/games/NCAAF_20190830_UTAHST_WAKE.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190906_WAKE@RICE/
#   --> This file is 102.1kB.
# data/games/NCAAF_20190906_WAKE_RICE.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190913_UNC@WAKE/
#   --> This file is 109.4kB.
# data/games/NCAAF_20190913_UNC_WAKE.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190921_ELON@WAKE/
#   --> This file is 105.1kB.
# data/games/NCAAF_20190921_ELON_WAKE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190928_WAKE@BC/
#   --> This file is 108.9kB.
# data/games/NCAAF_20190928_WAKE_BC.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191012_LVILLE@WAKE/
#   --> This file is 114.9kB.
# data/games/NCAAF_20191012_LVILLE_WAKE.p size -> 115 kB
# /college-football/gametracker/recap/NCAAF_20191019_FSU@WAKE/
#   --> This file is 111.1kB.
# data/games/NCAAF_20191019_FSU_WAKE.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190829_KENTST@ARIZST/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190829_KENTST_ARIZST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190906_SACST@ARIZST/
#   --> This file is 106.4kB.
# data/games/NCAAF_20190906_SACST_ARIZST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_ARIZST@MICHST/
#   --> This file is 104.9kB.
# data/games/NCAAF_20190914_ARIZST_MICHST.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190921_COLO@ARIZST/
#   --> This file is 103.9kB.
# data/games/NCAAF_20190921_COLO_ARIZST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190927_ARIZST@CAL/
#   --> This file is 100.2kB.
# data/games/NCAAF_20190927_ARIZST_CAL.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20191012_WASHST@ARIZST/
#   --> This file is 106.7kB.
# data/games/NCAAF_20191012_WASHST_ARIZST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191019_ARIZST@UTAH/
#   --> This file is 106.3kB.
# data/games/NCAAF_20191019_ARIZST_UTAH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190829_GATECH@CLEM/
#   --> This file is 113.9kB.
# data/games/NCAAF_20190829_GATECH_CLEM.p size -> 114 kB
# /college-football/gametracker/recap/NCAAF_20190907_SFLA@GATECH/
#   --> This file is 107.1kB.
# data/games/NCAAF_20190907_SFLA_GATECH.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_CIT@GATECH/
#   --> This file is 98.4kB.
# data/games/NCAAF_20190914_CIT_GATECH.p size -> 98 kB
# /college-football/gametracker/recap/NCAAF_20190928_GATECH@TEMPLE/
#   --> This file is 104.9kB.
# data/games/NCAAF_20190928_GATECH_TEMPLE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191005_UNC@GATECH/
#   --> This file is 108.7kB.
# data/games/NCAAF_20191005_UNC_GATECH.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191012_GATECH@DUKE/
#   --> This file is 109.4kB.
# data/games/NCAAF_20191012_GATECH_DUKE.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191019_GATECH@MIAMI/
#   --> This file is 106.9kB.
# data/games/NCAAF_20191019_GATECH_MIAMI.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_CUSE@LIB/
#   --> This file is 107.0kB.
# data/games/NCAAF_20190831_CUSE_LIB.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190907_CUSE@MD/
#   --> This file is 105.4kB.
# data/games/NCAAF_20190907_CUSE_MD.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190914_CLEM@CUSE/
#   --> This file is 113.4kB.
# data/games/NCAAF_20190914_CLEM_CUSE.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190921_WMICH@CUSE/
#   --> This file is 107.7kB.
# data/games/NCAAF_20190921_WMICH_CUSE.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_HOLY@CUSE/
#   --> This file is 108.1kB.
# data/games/NCAAF_20190928_HOLY_CUSE.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191010_CUSE@NCST/
#   --> This file is 105.3kB.
# data/games/NCAAF_20191010_CUSE_NCST.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191018_PITT@CUSE/
#   --> This file is 106.5kB.
# data/games/NCAAF_20191018_PITT_CUSE.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_TOLEDO@UK/
#   --> This file is 109.6kB.
# data/games/NCAAF_20190831_TOLEDO_UK.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_EMICH@UK/
#   --> This file is 109.0kB.
# data/games/NCAAF_20190907_EMICH_UK.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190914_FLA@UK/
#   --> This file is 105.9kB.
# data/games/NCAAF_20190914_FLA_UK.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190921_UK@MISSST/
#   --> This file is 103.4kB.
# data/games/NCAAF_20190921_UK_MISSST.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190928_UK@SC/
# /college-football/gametracker/recap/NCAAF_20191012_ARK@UK/
#   --> This file is 104.0kB.
# data/games/NCAAF_20191012_ARK_UK.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191019_UK@UGA/
#   --> This file is 102.4kB.
# data/games/NCAAF_20191019_UK_UGA.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190829_GRDWB@CHARLO/
# /college-football/gametracker/recap/NCAAF_20190907_CHARLO@APLST/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190907_CHARLO_APLST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190914_MA@CHARLO/
#   --> This file is 106.1kB.
# data/games/NCAAF_20190914_MA_CHARLO.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190921_CHARLO@CLEM/
#   --> This file is 110.0kB.
# data/games/NCAAF_20190921_CHARLO_CLEM.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190928_FAU@CHARLO/
#   --> This file is 110.0kB.
# data/games/NCAAF_20190928_FAU_CHARLO.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20191012_CHARLO@FIU/
#   --> This file is 101.4kB.
# data/games/NCAAF_20191012_CHARLO_FIU.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191019_CHARLO@WKY/
#   --> This file is 101.0kB.
# data/games/NCAAF_20191019_CHARLO_WKY.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190824_ARIZ@HAWAII/
#   --> This file is 112.0kB.
# data/games/NCAAF_20190824_ARIZ_HAWAII.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190907_NAZ@ARIZ/
#   --> This file is 113.0kB.
# data/games/NCAAF_20190907_NAZ_ARIZ.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190914_TXTECH@ARIZ/
#   --> This file is 108.6kB.
# data/games/NCAAF_20190914_TXTECH_ARIZ.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190928_UCLA@ARIZ/
#   --> This file is 107.3kB.
# data/games/NCAAF_20190928_UCLA_ARIZ.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_ARIZ@COLO/
#   --> This file is 106.6kB.
# data/games/NCAAF_20191005_ARIZ_COLO.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191012_WASH@ARIZ/
#   --> This file is 110.7kB.
# data/games/NCAAF_20191012_WASH_ARIZ.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20191019_ARIZ@USC/
#   --> This file is 111.7kB.
# data/games/NCAAF_20191019_ARIZ_USC.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190831_NWEST@STNFRD/
#   --> This file is 107.2kB.
# data/games/NCAAF_20190831_NWEST_STNFRD.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190907_STNFRD@USC/
#   --> This file is 107.0kB.
# data/games/NCAAF_20190907_STNFRD_USC.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_STNFRD@UCF/
#   --> This file is 110.5kB.
# data/games/NCAAF_20190914_STNFRD_UCF.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190921_OREG@STNFRD/
#   --> This file is 103.6kB.
# data/games/NCAAF_20190921_OREG_STNFRD.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190928_STNFRD@OREGST/
#   --> This file is 105.0kB.
# data/games/NCAAF_20190928_STNFRD_OREGST.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191005_WASH@STNFRD/
#   --> This file is 104.3kB.
# data/games/NCAAF_20191005_WASH_STNFRD.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191017_UCLA@STNFRD/
#   --> This file is 107.8kB.
# data/games/NCAAF_20191017_UCLA_STNFRD.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190830_PURDUE@NEVADA/
#   --> This file is 112.0kB.
# data/games/NCAAF_20190830_PURDUE_NEVADA.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190907_VANDY@PURDUE/
#   --> This file is 110.3kB.
# data/games/NCAAF_20190907_VANDY_PURDUE.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190914_TCU@PURDUE/
#   --> This file is 107.9kB.
# data/games/NCAAF_20190914_TCU_PURDUE.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_MINN@PURDUE/
#   --> This file is 106.7kB.
# data/games/NCAAF_20190928_MINN_PURDUE.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_PURDUE@PSU/
#   --> This file is 107.2kB.
# data/games/NCAAF_20191005_PURDUE_PSU.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191012_MD@PURDUE/
#   --> This file is 108.8kB.
# data/games/NCAAF_20191012_MD_PURDUE.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191019_PURDUE@IOWA/
#   --> This file is 106.9kB.
# data/games/NCAAF_20191019_PURDUE_IOWA.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_EMICH@CSTCAR/
#   --> This file is 107.0kB.
# data/games/NCAAF_20190831_EMICH_CSTCAR.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190907_CSTCAR@KANSAS/
# /college-football/gametracker/recap/NCAAF_20190914_NRFST@CSTCAR/
#   --> This file is 100.2kB.
# data/games/NCAAF_20190914_NRFST_CSTCAR.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190921_CSTCAR@MA/
#   --> This file is 103.9kB.
# data/games/NCAAF_20190921_CSTCAR_MA.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190928_CSTCAR@APLST/
#   --> This file is 107.2kB.
# data/games/NCAAF_20190928_CSTCAR_APLST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191012_GAST@CSTCAR/
#   --> This file is 99.2kB.
# data/games/NCAAF_20191012_GAST_CSTCAR.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20191019_CSTCAR@GAS/
#   --> This file is 99.0kB.
# data/games/NCAAF_20191019_CSTCAR_GAS.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20190831_NWEST@STNFRD/
# /college-football/gametracker/recap/NCAAF_20190914_UNLV@NWEST/
#   --> This file is 108.2kB.
# data/games/NCAAF_20190914_UNLV_NWEST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190921_MICHST@NWEST/
#   --> This file is 103.8kB.
# data/games/NCAAF_20190921_MICHST_NWEST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190928_NWEST@WISC/
#   --> This file is 109.7kB.
# data/games/NCAAF_20190928_NWEST_WISC.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20191005_NWEST@NEB/
#   --> This file is 107.1kB.
# data/games/NCAAF_20191005_NWEST_NEB.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191018_OHIOST@NWEST/
#   --> This file is 107.9kB.
# data/games/NCAAF_20191018_OHIOST_NWEST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190824_MIAMI@FLA/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190824_MIAMI_FLA.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190907_TNMART@FLA/
#   --> This file is 108.9kB.
# data/games/NCAAF_20190907_TNMART_FLA.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190914_FLA@UK/
# /college-football/gametracker/recap/NCAAF_20190921_TENN@FLA/
#   --> This file is 107.5kB.
# data/games/NCAAF_20190921_TENN_FLA.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_TWST@FLA/
#   --> This file is 101.2kB.
# data/games/NCAAF_20190928_TWST_FLA.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191005_AUBURN@FLA/
#   --> This file is 109.9kB.
# data/games/NCAAF_20191005_AUBURN_FLA.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20191012_FLA@LSU/
#   --> This file is 104.7kB.
# data/games/NCAAF_20191012_FLA_LSU.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191019_FLA@SC/
# /college-football/gametracker/recap/NCAAF_20190830_MA@RUT/
#   --> This file is 110.3kB.
# data/games/NCAAF_20190830_MA_RUT.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_SIL@MA/
#   --> This file is 109.6kB.
# data/games/NCAAF_20190907_SIL_MA.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190914_MA@CHARLO/
# /college-football/gametracker/recap/NCAAF_20190921_CSTCAR@MA/
# /college-football/gametracker/recap/NCAAF_20190928_AKRON@MA/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190928_AKRON_MA.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191005_MA@FIU/
#   --> This file is 105.6kB.
# data/games/NCAAF_20191005_MA_FIU.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191012_MA@LATECH/
#   --> This file is 111.4kB.
# data/games/NCAAF_20191012_MA_LATECH.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190829_FIU@TULANE/
#   --> This file is 101.4kB.
# data/games/NCAAF_20190829_FIU_TULANE.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190907_WKY@FIU/
#   --> This file is 104.7kB.
# data/games/NCAAF_20190907_WKY_FIU.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190914_NH@FIU/
# /college-football/gametracker/recap/NCAAF_20190920_FIU@LATECH/
#   --> This file is 106.6kB.
# data/games/NCAAF_20190920_FIU_LATECH.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_MA@FIU/
# /college-football/gametracker/recap/NCAAF_20191012_CHARLO@FIU/
# /college-football/gametracker/recap/NCAAF_20191019_UTEP@FIU/
#   --> This file is 96.4kB.
# data/games/NCAAF_20191019_UTEP_FIU.p size -> 96 kB
# /college-football/gametracker/recap/NCAAF_20190829_GATECH@CLEM/
# /college-football/gametracker/recap/NCAAF_20190907_TXAM@CLEM/
#   --> This file is 106.8kB.
# data/games/NCAAF_20190907_TXAM_CLEM.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_CLEM@CUSE/
# /college-football/gametracker/recap/NCAAF_20190921_CHARLO@CLEM/
# /college-football/gametracker/recap/NCAAF_20190928_CLEM@UNC/
#   --> This file is 103.6kB.
# data/games/NCAAF_20190928_CLEM_UNC.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191012_FSU@CLEM/
#   --> This file is 113.5kB.
# data/games/NCAAF_20191012_FSU_CLEM.p size -> 114 kB
# /college-football/gametracker/recap/NCAAF_20191019_CLEM@LVILLE/
#   --> This file is 109.2kB.
# data/games/NCAAF_20191019_CLEM_LVILLE.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190831_LATECH@TEXAS/
#   --> This file is 105.8kB.
# data/games/NCAAF_20190831_LATECH_TEXAS.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190907_GRAM@LATECH/
#   --> This file is 106.5kB.
# data/games/NCAAF_20190907_GRAM_LATECH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_LATECH@BGREEN/
#   --> This file is 109.1kB.
# data/games/NCAAF_20190914_LATECH_BGREEN.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190920_FIU@LATECH/
# /college-football/gametracker/recap/NCAAF_20190928_LATECH@RICE/
#   --> This file is 104.4kB.
# data/games/NCAAF_20190928_LATECH_RICE.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191012_MA@LATECH/
# /college-football/gametracker/recap/NCAAF_20191019_USM@LATECH/
#   --> This file is 106.0kB.
# data/games/NCAAF_20191019_USM_LATECH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190831_MONNJ@WMICH/
# /college-football/gametracker/recap/NCAAF_20190907_WMICH@MICHST/
#   --> This file is 104.1kB.
# data/games/NCAAF_20190907_WMICH_MICHST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190914_GAST@WMICH/
# /college-football/gametracker/recap/NCAAF_20190921_WMICH@CUSE/
# /college-football/gametracker/recap/NCAAF_20190928_CMICH@WMICH/
#   --> This file is 106.4kB.
# data/games/NCAAF_20190928_CMICH_WMICH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191005_WMICH@TOLEDO/
#   --> This file is 102.1kB.
# data/games/NCAAF_20191005_WMICH_TOLEDO.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20191012_MIAOH@WMICH/
#   --> This file is 108.6kB.
# data/games/NCAAF_20191012_MIAOH_WMICH.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191019_WMICH@EMICH/
#   --> This file is 98.2kB.
# data/games/NCAAF_20191019_WMICH_EMICH.p size -> 98 kB
# /college-football/gametracker/recap/NCAAF_20190831_GAS@LSU/
#   --> This file is 110.2kB.
# data/games/NCAAF_20190831_GAS_LSU.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_LSU@TEXAS/
#   --> This file is 109.3kB.
# data/games/NCAAF_20190907_LSU_TEXAS.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190914_NWST@LSU/
#   --> This file is 105.4kB.
# data/games/NCAAF_20190914_NWST_LSU.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190921_LSU@VANDY/
#   --> This file is 114.7kB.
# data/games/NCAAF_20190921_LSU_VANDY.p size -> 115 kB
# /college-football/gametracker/recap/NCAAF_20191005_UTAHST@LSU/
#   --> This file is 108.1kB.
# data/games/NCAAF_20191005_UTAHST_LSU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191012_FLA@LSU/
# /college-football/gametracker/recap/NCAAF_20191019_LSU@MISSST/
#   --> This file is 108.5kB.
# data/games/NCAAF_20191019_LSU_MISSST.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190831_SMU@ARKST/
#   --> This file is 110.5kB.
# data/games/NCAAF_20190831_SMU_ARKST.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190907_NTEXAS@SMU/
#   --> This file is 104.9kB.
# data/games/NCAAF_20190907_NTEXAS_SMU.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190914_TXSTSM@SMU/
#   --> This file is 110.7kB.
# data/games/NCAAF_20190914_TXSTSM_SMU.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190921_SMU@TCU/
#   --> This file is 112.0kB.
# data/games/NCAAF_20190921_SMU_TCU.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190928_SMU@SFLA/
# /college-football/gametracker/recap/NCAAF_20191005_TULSA@SMU/
# /college-football/gametracker/recap/NCAAF_20191019_TEMPLE@SMU/
#   --> This file is 112.8kB.
# data/games/NCAAF_20191019_TEMPLE_SMU.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190831_FRESNO@USC/
#   --> This file is 110.2kB.
# data/games/NCAAF_20190831_FRESNO_USC.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_MINN@FRESNO/
#   --> This file is 107.1kB.
# data/games/NCAAF_20190907_MINN_FRESNO.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190921_SACST@FRESNO/
#   --> This file is 104.3kB.
# data/games/NCAAF_20190921_SACST_FRESNO.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190928_FRESNO@NMEXST/
#   --> This file is 105.1kB.
# data/games/NCAAF_20190928_FRESNO_NMEXST.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191012_FRESNO@AF/
#   --> This file is 98.7kB.
# data/games/NCAAF_20191012_FRESNO_AF.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20191018_UNLV@FRESNO/
#   --> This file is 108.1kB.
# data/games/NCAAF_20191018_UNLV_FRESNO.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190901_HOU@OKLA/
# /college-football/gametracker/recap/NCAAF_20190907_PRARIE@HOU/
#   --> This file is 109.0kB.
# data/games/NCAAF_20190907_PRARIE_HOU.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190913_WASHST@HOU/
#   --> This file is 106.1kB.
# data/games/NCAAF_20190913_WASHST_HOU.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190919_HOU@TULANE/
#   --> This file is 107.5kB.
# data/games/NCAAF_20190919_HOU_TULANE.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_HOU@NTEXAS/
#   --> This file is 106.0kB.
# data/games/NCAAF_20190928_HOU_NTEXAS.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191012_CINCY@HOU/
#   --> This file is 107.5kB.
# data/games/NCAAF_20191012_CINCY_HOU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191019_HOU@UCONN/
# /college-football/gametracker/recap/NCAAF_20190830_OKLAST@OREGST/
#   --> This file is 106.6kB.
# data/games/NCAAF_20190830_OKLAST_OREGST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190907_MCN@OKLAST/
#   --> This file is 112.6kB.
# data/games/NCAAF_20190907_MCN_OKLAST.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190914_OKLAST@TULSA/
# /college-football/gametracker/recap/NCAAF_20190921_OKLAST@TEXAS/
#   --> This file is 110.6kB.
# data/games/NCAAF_20190921_OKLAST_TEXAS.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190928_KSTATE@OKLAST/
#   --> This file is 106.1kB.
# data/games/NCAAF_20190928_KSTATE_OKLAST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191005_OKLAST@TXTECH/
#   --> This file is 113.0kB.
# data/games/NCAAF_20191005_OKLAST_TXTECH.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20191019_BAYLOR@OKLAST/
#   --> This file is 110.1kB.
# data/games/NCAAF_20191019_BAYLOR_OKLAST.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190831_DUKE@BAMA/
#   --> This file is 109.4kB.
# data/games/NCAAF_20190831_DUKE_BAMA.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190907_NCAT@DUKE/
#   --> This file is 110.0kB.
# data/games/NCAAF_20190907_NCAT_DUKE.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190914_DUKE@MTSU/
# /college-football/gametracker/recap/NCAAF_20190927_DUKE@VATECH/
#   --> This file is 107.1kB.
# data/games/NCAAF_20190927_DUKE_VATECH.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_PITT@DUKE/
#   --> This file is 116.4kB.
# data/games/NCAAF_20191005_PITT_DUKE.p size -> 116 kB
# /college-football/gametracker/recap/NCAAF_20191012_GATECH@DUKE/
# /college-football/gametracker/recap/NCAAF_20191019_DUKE@UVA/
#   --> This file is 108.9kB.
# data/games/NCAAF_20191019_DUKE_UVA.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190830_MA@RUT/
# /college-football/gametracker/recap/NCAAF_20190907_RUT@IOWA/
#   --> This file is 100.1kB.
# data/games/NCAAF_20190907_RUT_IOWA.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190921_BC@RUT/
#   --> This file is 108.2kB.
# data/games/NCAAF_20190921_BC_RUT.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_RUT@MICH/
#   --> This file is 106.9kB.
# data/games/NCAAF_20190928_RUT_MICH.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_MD@RUT/
#   --> This file is 108.9kB.
# data/games/NCAAF_20191005_MD_RUT.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191012_RUT@IND/
#   --> This file is 104.8kB.
# data/games/NCAAF_20191012_RUT_IND.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191019_MINN@RUT/
#   --> This file is 105.6kB.
# data/games/NCAAF_20191019_MINN_RUT.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190831_ALCORN@USM/
#   --> This file is 102.4kB.
# data/games/NCAAF_20190831_ALCORN_USM.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190907_USM@MISSST/
#   --> This file is 106.0kB.
# data/games/NCAAF_20190907_USM_MISSST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_USM@TROY/
# /college-football/gametracker/recap/NCAAF_20190921_USM@BAMA/
#   --> This file is 99.9kB.
# data/games/NCAAF_20190921_USM_BAMA.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190928_UTEP@USM/
#   --> This file is 103.7kB.
# data/games/NCAAF_20190928_UTEP_USM.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191012_NTEXAS@USM/
#   --> This file is 101.3kB.
# data/games/NCAAF_20191012_NTEXAS_USM.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191019_USM@LATECH/
# /college-football/gametracker/recap/NCAAF_20190831_ECU@NCST/
#   --> This file is 110.0kB.
# data/games/NCAAF_20190831_ECU_NCST.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_GRDWB@ECU/
#   --> This file is 102.1kB.
# data/games/NCAAF_20190907_GRDWB_ECU.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190914_ECU@NAVY/
#   --> This file is 106.2kB.
# data/games/NCAAF_20190914_ECU_NAVY.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190921_WMMARY@ECU/
#   --> This file is 102.5kB.
# data/games/NCAAF_20190921_WMMARY_ECU.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190928_ECU@ODU/
#   --> This file is 101.6kB.
# data/games/NCAAF_20190928_ECU_ODU.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20191003_TEMPLE@ECU/
#   --> This file is 106.9kB.
# data/games/NCAAF_20191003_TEMPLE_ECU.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191019_ECU@UCF/
#   --> This file is 112.4kB.
# data/games/NCAAF_20191019_ECU_UCF.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190831_NRFST@ODU/
#   --> This file is 100.1kB.
# data/games/NCAAF_20190831_NRFST_ODU.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190907_ODU@VATECH/
#   --> This file is 103.2kB.
# data/games/NCAAF_20190907_ODU_VATECH.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190921_ODU@UVA/
#   --> This file is 105.5kB.
# data/games/NCAAF_20190921_ODU_UVA.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190928_ECU@ODU/
# /college-football/gametracker/recap/NCAAF_20191005_WKY@ODU/
#   --> This file is 100.5kB.
# data/games/NCAAF_20191005_WKY_ODU.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191012_ODU@MRSHL/
#   --> This file is 105.1kB.
# data/games/NCAAF_20191012_ODU_MRSHL.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191019_ODU@UAB/
#   --> This file is 106.0kB.
# data/games/NCAAF_20191019_ODU_UAB.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190831_EWASH@WASH/
#   --> This file is 110.1kB.
# data/games/NCAAF_20190831_EWASH_WASH.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_CAL@WASH/
#   --> This file is 106.2kB.
# data/games/NCAAF_20190907_CAL_WASH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_HAWAII@WASH/
#   --> This file is 108.6kB.
# data/games/NCAAF_20190914_HAWAII_WASH.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190921_WASH@BYU/
#   --> This file is 108.1kB.
# data/games/NCAAF_20190921_WASH_BYU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_USC@WASH/
#   --> This file is 105.8kB.
# data/games/NCAAF_20190928_USC_WASH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191005_WASH@STNFRD/
# /college-football/gametracker/recap/NCAAF_20191012_WASH@ARIZ/
# /college-football/gametracker/recap/NCAAF_20191019_OREG@WASH/
#   --> This file is 109.0kB.
# data/games/NCAAF_20191019_OREG_WASH.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190831_MTSU@MICH/
# /college-football/gametracker/recap/NCAAF_20190907_ARMY@MICH/
#   --> This file is 105.9kB.
# data/games/NCAAF_20190907_ARMY_MICH.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190921_MICH@WISC/
#   --> This file is 108.0kB.
# data/games/NCAAF_20190921_MICH_WISC.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_RUT@MICH/
# /college-football/gametracker/recap/NCAAF_20191005_IOWA@MICH/
#   --> This file is 104.5kB.
# data/games/NCAAF_20191005_IOWA_MICH.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191012_MICH@ILL/
#   --> This file is 106.8kB.
# data/games/NCAAF_20191012_MICH_ILL.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191019_MICH@PSU/
#   --> This file is 107.7kB.
# data/games/NCAAF_20191019_MICH_PSU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190829_UCLA@CINCY/
#   --> This file is 108.8kB.
# data/games/NCAAF_20190829_UCLA_CINCY.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190907_SDGST@UCLA/
#   --> This file is 107.3kB.
# data/games/NCAAF_20190907_SDGST_UCLA.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_OKLA@UCLA/
# /college-football/gametracker/recap/NCAAF_20190921_UCLA@WASHST/
#   --> This file is 113.5kB.
# data/games/NCAAF_20190921_UCLA_WASHST.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190928_UCLA@ARIZ/
# /college-football/gametracker/recap/NCAAF_20191005_OREGST@UCLA/
#   --> This file is 104.7kB.
# data/games/NCAAF_20191005_OREGST_UCLA.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191017_UCLA@STNFRD/
# /college-football/gametracker/recap/NCAAF_20190829_UCLA@CINCY/
# /college-football/gametracker/recap/NCAAF_20190907_CINCY@OHIOST/
#   --> This file is 106.5kB.
# data/games/NCAAF_20190907_CINCY_OHIOST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_MIAOH@CINCY/
#   --> This file is 108.9kB.
# data/games/NCAAF_20190914_MIAOH_CINCY.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190928_CINCY@MRSHL/
#   --> This file is 110.4kB.
# data/games/NCAAF_20190928_CINCY_MRSHL.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20191004_UCF@CINCY/
#   --> This file is 110.8kB.
# data/games/NCAAF_20191004_UCF_CINCY.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20191012_CINCY@HOU/
# /college-football/gametracker/recap/NCAAF_20191019_TULSA@CINCY/
# /college-football/gametracker/recap/NCAAF_20190831_DAVIS@CAL/
#   --> This file is 105.8kB.
# data/games/NCAAF_20190831_DAVIS_CAL.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190907_CAL@WASH/
# /college-football/gametracker/recap/NCAAF_20190914_NTEXAS@CAL/
#   --> This file is 108.8kB.
# data/games/NCAAF_20190914_NTEXAS_CAL.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190921_CAL@MISS/
#   --> This file is 108.5kB.
# data/games/NCAAF_20190921_CAL_MISS.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190927_ARIZST@CAL/
# /college-football/gametracker/recap/NCAAF_20191005_CAL@OREG/
#   --> This file is 105.2kB.
# data/games/NCAAF_20191005_CAL_OREG.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191019_OREGST@CAL/
#   --> This file is 108.2kB.
# data/games/NCAAF_20191019_OREGST_CAL.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190831_MIAOH@IOWA/
#   --> This file is 105.3kB.
# data/games/NCAAF_20190831_MIAOH_IOWA.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190907_TNTECH@MIAOH/
#   --> This file is 103.6kB.
# data/games/NCAAF_20190907_TNTECH_MIAOH.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190914_MIAOH@CINCY/
# /college-football/gametracker/recap/NCAAF_20190921_MIAOH@OHIOST/
#   --> This file is 112.7kB.
# data/games/NCAAF_20190921_MIAOH_OHIOST.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190928_BUFF@MIAOH/
#   --> This file is 107.7kB.
# data/games/NCAAF_20190928_BUFF_MIAOH.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191012_MIAOH@WMICH/
# /college-football/gametracker/recap/NCAAF_20191019_NILL@MIAOH/
#   --> This file is 104.1kB.
# data/games/NCAAF_20191019_NILL_MIAOH.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190831_SMU@ARKST/
# /college-football/gametracker/recap/NCAAF_20190907_ARKST@UNLV/
#   --> This file is 107.9kB.
# data/games/NCAAF_20190907_ARKST_UNLV.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190914_ARKST@UGA/
#   --> This file is 104.3kB.
# data/games/NCAAF_20190914_ARKST_UGA.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190921_SIL@ARKST/
#   --> This file is 98.8kB.
# data/games/NCAAF_20190921_SIL_ARKST.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20190928_ARKST@TROY/
#   --> This file is 108.1kB.
# data/games/NCAAF_20190928_ARKST_TROY.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191005_ARKST@GAST/
#   --> This file is 107.7kB.
# data/games/NCAAF_20191005_ARKST_GAST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191017_LALAF@ARKST/
#   --> This file is 106.9kB.
# data/games/NCAAF_20191017_LALAF_ARKST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_UVA@PITT/
#   --> This file is 104.4kB.
# data/games/NCAAF_20190831_UVA_PITT.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190907_OHIO@PITT/
#   --> This file is 103.2kB.
# data/games/NCAAF_20190907_OHIO_PITT.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190914_PITT@PSU/
#   --> This file is 107.2kB.
# data/games/NCAAF_20190914_PITT_PSU.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190921_UCF@PITT/
#   --> This file is 113.4kB.
# data/games/NCAAF_20190921_UCF_PITT.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190928_DE@PITT/
#   --> This file is 101.7kB.
# data/games/NCAAF_20190928_DE_PITT.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20191005_PITT@DUKE/
# /college-football/gametracker/recap/NCAAF_20191018_PITT@CUSE/
# /college-football/gametracker/recap/NCAAF_20190831_IND@BALLST/
#   --> This file is 111.1kB.
# data/games/NCAAF_20190831_IND_BALLST.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190907_EIL@IND/
#   --> This file is 111.0kB.
# data/games/NCAAF_20190907_EIL_IND.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190914_OHIOST@IND/
#   --> This file is 111.2kB.
# data/games/NCAAF_20190914_OHIOST_IND.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190921_UCONN@IND/
# /college-football/gametracker/recap/NCAAF_20190928_IND@MICHST/
#   --> This file is 109.2kB.
# data/games/NCAAF_20190928_IND_MICHST.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191012_RUT@IND/
# /college-football/gametracker/recap/NCAAF_20191019_IND@MD/
#   --> This file is 109.5kB.
# data/games/NCAAF_20191019_IND_MD.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190831_RI@OHIO/
#   --> This file is 100.4kB.
# data/games/NCAAF_20190831_RI_OHIO.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190907_OHIO@PITT/
# /college-football/gametracker/recap/NCAAF_20190914_OHIO@MRSHL/
#   --> This file is 104.0kB.
# data/games/NCAAF_20190914_OHIO_MRSHL.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190921_LALAF@OHIO/
#   --> This file is 111.5kB.
# data/games/NCAAF_20190921_LALAF_OHIO.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20191005_OHIO@BUFF/
#   --> This file is 95.0kB.
# data/games/NCAAF_20191005_OHIO_BUFF.p size -> 95 kB
# /college-football/gametracker/recap/NCAAF_20191012_NILL@OHIO/
#   --> This file is 104.8kB.
# data/games/NCAAF_20191012_NILL_OHIO.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191019_KENTST@OHIO/
#   --> This file is 107.0kB.
# data/games/NCAAF_20191019_KENTST_OHIO.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_WBRST@SDGST/
#   --> This file is 103.9kB.
# data/games/NCAAF_20190831_WBRST_SDGST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190907_SDGST@UCLA/
# /college-football/gametracker/recap/NCAAF_20190914_SDGST@NMEXST/
#   --> This file is 101.9kB.
# data/games/NCAAF_20190914_SDGST_NMEXST.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190921_UTAHST@SDGST/
#   --> This file is 100.4kB.
# data/games/NCAAF_20190921_UTAHST_SDGST.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20191005_SDGST@COLOST/
#   --> This file is 103.3kB.
# data/games/NCAAF_20191005_SDGST_COLOST.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20191012_WYO@SDGST/
#   --> This file is 100.4kB.
# data/games/NCAAF_20191012_WYO_SDGST.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20191019_SDGST@SJST/
#   --> This file is 103.9kB.
# data/games/NCAAF_20191019_SDGST_SJST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190831_SUT@UNLV/
#   --> This file is 106.1kB.
# data/games/NCAAF_20190831_SUT_UNLV.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190907_ARKST@UNLV/
# /college-football/gametracker/recap/NCAAF_20190914_UNLV@NWEST/
# /college-football/gametracker/recap/NCAAF_20190928_UNLV@WYO/
#   --> This file is 107.1kB.
# data/games/NCAAF_20190928_UNLV_WYO.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_BOISE@UNLV/
#   --> This file is 110.6kB.
# data/games/NCAAF_20191005_BOISE_UNLV.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20191012_UNLV@VANDY/
#   --> This file is 104.0kB.
# data/games/NCAAF_20191012_UNLV_VANDY.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191018_UNLV@FRESNO/
# /college-football/gametracker/recap/NCAAF_20190830_RICE@ARMY/
#   --> This file is 101.4kB.
# data/games/NCAAF_20190830_RICE_ARMY.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190907_ARMY@MICH/
# /college-football/gametracker/recap/NCAAF_20190914_ARMY@TXSA/
#   --> This file is 105.1kB.
# data/games/NCAAF_20190914_ARMY_TXSA.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190921_MRGNST@ARMY/
#   --> This file is 100.9kB.
# data/games/NCAAF_20190921_MRGNST_ARMY.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191005_TULANE@ARMY/
#   --> This file is 106.6kB.
# data/games/NCAAF_20191005_TULANE_ARMY.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191012_ARMY@WKY/
#   --> This file is 99.6kB.
# data/games/NCAAF_20191012_ARMY_WKY.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20191019_ARMY@GAST/
#   --> This file is 100.9kB.
# data/games/NCAAF_20191019_ARMY_GAST.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190831_ARPB@TCU/
#   --> This file is 107.0kB.
# data/games/NCAAF_20190831_ARPB_TCU.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190914_TCU@PURDUE/
# /college-football/gametracker/recap/NCAAF_20190921_SMU@TCU/
# /college-football/gametracker/recap/NCAAF_20190928_KANSAS@TCU/
# /college-football/gametracker/recap/NCAAF_20191005_TCU@IOWAST/
#   --> This file is 106.7kB.
# data/games/NCAAF_20191005_TCU_IOWAST.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191019_TCU@KSTATE/
#   --> This file is 100.5kB.
# data/games/NCAAF_20191019_TCU_KSTATE.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190831_AKRON@ILL/
#   --> This file is 109.9kB.
# data/games/NCAAF_20190831_AKRON_ILL.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_ILL@UCONN/
# /college-football/gametracker/recap/NCAAF_20190914_EMICH@ILL/
#   --> This file is 111.1kB.
# data/games/NCAAF_20190914_EMICH_ILL.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190921_NEB@ILL/
#   --> This file is 108.0kB.
# data/games/NCAAF_20190921_NEB_ILL.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191005_ILL@MINN/
#   --> This file is 106.7kB.
# data/games/NCAAF_20191005_ILL_MINN.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191012_MICH@ILL/
# /college-football/gametracker/recap/NCAAF_20191019_WISC@ILL/
#   --> This file is 106.1kB.
# data/games/NCAAF_20191019_WISC_ILL.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190830_OKLAST@OREGST/
# /college-football/gametracker/recap/NCAAF_20190908_OREGST@HAWAII/
# /college-football/gametracker/recap/NCAAF_20190914_CPOLY@OREGST/
#   --> This file is 98.6kB.
# data/games/NCAAF_20190914_CPOLY_OREGST.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20190928_STNFRD@OREGST/
# /college-football/gametracker/recap/NCAAF_20191005_OREGST@UCLA/
# /college-football/gametracker/recap/NCAAF_20191012_UTAH@OREGST/
#   --> This file is 106.3kB.
# data/games/NCAAF_20191012_UTAH_OREGST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191019_OREGST@CAL/
# /college-football/gametracker/recap/NCAAF_20190831_OREG@AUBURN/
#   --> This file is 111.1kB.
# data/games/NCAAF_20190831_OREG_AUBURN.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190907_TULANE@AUBURN/
#   --> This file is 97.2kB.
# data/games/NCAAF_20190907_TULANE_AUBURN.p size -> 97 kB
# /college-football/gametracker/recap/NCAAF_20190914_KENTST@AUBURN/
#   --> This file is 111.1kB.
# data/games/NCAAF_20190914_KENTST_AUBURN.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190921_AUBURN@TXAM/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190921_AUBURN_TXAM.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_MISSST@AUBURN/
#   --> This file is 109.0kB.
# data/games/NCAAF_20190928_MISSST_AUBURN.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191005_AUBURN@FLA/
# /college-football/gametracker/recap/NCAAF_20191019_AUBURN@ARK/
#   --> This file is 110.1kB.
# data/games/NCAAF_20191019_AUBURN_ARK.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190831_ETNST@APLST/
#   --> This file is 106.4kB.
# data/games/NCAAF_20190831_ETNST_APLST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190907_CHARLO@APLST/
# /college-football/gametracker/recap/NCAAF_20190921_APLST@UNC/
#   --> This file is 108.5kB.
# data/games/NCAAF_20190921_APLST_UNC.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_CSTCAR@APLST/
# /college-football/gametracker/recap/NCAAF_20191009_APLST@LALAF/
#   --> This file is 102.2kB.
# data/games/NCAAF_20191009_APLST_LALAF.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20191019_LAMON@APLST/
#   --> This file is 105.7kB.
# data/games/NCAAF_20191019_LAMON_APLST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190830_UTAHST@WAKE/
# /college-football/gametracker/recap/NCAAF_20190907_STONYBRK@UTAHST/
#   --> This file is 107.5kB.
# data/games/NCAAF_20190907_STONYBRK_UTAHST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190921_UTAHST@SDGST/
# /college-football/gametracker/recap/NCAAF_20190928_COLOST@UTAHST/
#   --> This file is 109.6kB.
# data/games/NCAAF_20190928_COLOST_UTAHST.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20191005_UTAHST@LSU/
# /college-football/gametracker/recap/NCAAF_20191019_NEVADA@UTAHST/
#   --> This file is 109.9kB.
# data/games/NCAAF_20191019_NEVADA_UTAHST.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190830_COLOST@COLO/
#   --> This file is 108.6kB.
# data/games/NCAAF_20190830_COLOST_COLO.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190907_WIL@COLOST/
#   --> This file is 108.1kB.
# data/games/NCAAF_20190907_WIL_COLOST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190914_COLOST@ARK/
#   --> This file is 112.0kB.
# data/games/NCAAF_20190914_COLOST_ARK.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20190921_TOLEDO@COLOST/
#   --> This file is 107.9kB.
# data/games/NCAAF_20190921_TOLEDO_COLOST.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190928_COLOST@UTAHST/
# /college-football/gametracker/recap/NCAAF_20191005_SDGST@COLOST/
# /college-football/gametracker/recap/NCAAF_20191011_COLOST@NMEX/
#   --> This file is 108.6kB.
# data/games/NCAAF_20191011_COLOST_NMEX.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190831_BOISE@FSU/
#   --> This file is 109.9kB.
# data/games/NCAAF_20190831_BOISE_FSU.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190906_MRSHL@BOISE/
#   --> This file is 103.7kB.
# data/games/NCAAF_20190906_MRSHL_BOISE.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190914_PORTST@BOISE/
#   --> This file is 105.5kB.
# data/games/NCAAF_20190914_PORTST_BOISE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190920_AF@BOISE/
#   --> This file is 101.7kB.
# data/games/NCAAF_20190920_AF_BOISE.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20191005_BOISE@UNLV/
# /college-football/gametracker/recap/NCAAF_20191012_HAWAII@BOISE/
#   --> This file is 112.6kB.
# data/games/NCAAF_20191012_HAWAII_BOISE.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20191019_BOISE@BYU/
#   --> This file is 107.1kB.
# data/games/NCAAF_20191019_BOISE_BYU.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190831_SFA@BAYLOR/
#   --> This file is 107.0kB.
# data/games/NCAAF_20190831_SFA_BAYLOR.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190907_TXSA@BAYLOR/
#   --> This file is 111.1kB.
# data/games/NCAAF_20190907_TXSA_BAYLOR.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190921_BAYLOR@RICE/
#   --> This file is 104.9kB.
# data/games/NCAAF_20190921_BAYLOR_RICE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190928_IOWAST@BAYLOR/
#   --> This file is 107.7kB.
# data/games/NCAAF_20190928_IOWAST_BAYLOR.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191005_BAYLOR@KSTATE/
#   --> This file is 105.6kB.
# data/games/NCAAF_20191005_BAYLOR_KSTATE.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191012_TXTECH@BAYLOR/
#   --> This file is 106.9kB.
# data/games/NCAAF_20191012_TXTECH_BAYLOR.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191019_BAYLOR@OKLAST/
# /college-football/gametracker/recap/NCAAF_20190831_MISS@MEMP/
#   --> This file is 101.7kB.
# data/games/NCAAF_20190831_MISS_MEMP.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190907_ARK@MISS/
#   --> This file is 108.5kB.
# data/games/NCAAF_20190907_ARK_MISS.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20190914_SELOU@MISS/
#   --> This file is 106.9kB.
# data/games/NCAAF_20190914_SELOU_MISS.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190921_CAL@MISS/
# /college-football/gametracker/recap/NCAAF_20190928_MISS@BAMA/
#   --> This file is 112.0kB.
# data/games/NCAAF_20190928_MISS_BAMA.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20191005_VANDY@MISS/
#   --> This file is 105.9kB.
# data/games/NCAAF_20191005_VANDY_MISS.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191012_MISS@MIZZOU/
#   --> This file is 107.6kB.
# data/games/NCAAF_20191012_MISS_MIZZOU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191019_TXAM@MISS/
#   --> This file is 107.6kB.
# data/games/NCAAF_20191019_TXAM_MISS.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190831_JMAD@WVU/
#   --> This file is 107.7kB.
# data/games/NCAAF_20190831_JMAD_WVU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190907_WVU@MIZZOU/
#   --> This file is 108.5kB.
# data/games/NCAAF_20190907_WVU_MIZZOU.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190914_NCST@WVU/
#   --> This file is 106.2kB.
# data/games/NCAAF_20190914_NCST_WVU.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190921_WVU@KANSAS/
# /college-football/gametracker/recap/NCAAF_20191005_TEXAS@WVU/
#   --> This file is 111.7kB.
# data/games/NCAAF_20191005_TEXAS_WVU.p size -> 112 kB
# /college-football/gametracker/recap/NCAAF_20191012_IOWAST@WVU/
#   --> This file is 104.6kB.
# data/games/NCAAF_20191012_IOWAST_WVU.p size -> 105 kB
# ...
# /college-football/gametracker/recap/NCAAF_20190831_VMI@MRSHL/
#   --> This file is 105.6kB.
# data/games/NCAAF_20190831_VMI_MRSHL.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190906_MRSHL@BOISE/
# /college-football/gametracker/recap/NCAAF_20190914_OHIO@MRSHL/
# /college-football/gametracker/recap/NCAAF_20190928_CINCY@MRSHL/
# /college-football/gametracker/recap/NCAAF_20191005_MRSHL@MTSU/
# /college-football/gametracker/recap/NCAAF_20191012_ODU@MRSHL/
# /college-football/gametracker/recap/NCAAF_20191018_MRSHL@FAU/
# /college-football/gametracker/recap/NCAAF_20190831_COLG@AF/
#   --> This file is 106.1kB.
# data/games/NCAAF_20190831_COLG_AF.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_AF@COLO/
#   --> This file is 104.5kB.
# data/games/NCAAF_20190914_AF_COLO.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190920_AF@BOISE/
# /college-football/gametracker/recap/NCAAF_20190927_SJST@AF/
#   --> This file is 105.4kB.
# data/games/NCAAF_20190927_SJST_AF.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20191005_AF@NAVY/
# /college-football/gametracker/recap/NCAAF_20191012_FRESNO@AF/
# /college-football/gametracker/recap/NCAAF_20191019_AF@HAWAII/
# /college-football/gametracker/recap/NCAAF_20190831_ABIL@NTEXAS/
#   --> This file is 109.8kB.
# data/games/NCAAF_20190831_ABIL_NTEXAS.p size -> 110 kB
# /college-football/gametracker/recap/NCAAF_20190907_NTEXAS@SMU/
# /college-football/gametracker/recap/NCAAF_20190914_NTEXAS@CAL/
# /college-football/gametracker/recap/NCAAF_20190921_TXSA@NTEXAS/
# /college-football/gametracker/recap/NCAAF_20190928_HOU@NTEXAS/
# /college-football/gametracker/recap/NCAAF_20191012_NTEXAS@USM/
# /college-football/gametracker/recap/NCAAF_20191019_MTSU@NTEXAS/
# /college-football/gametracker/recap/NCAAF_20190829_MRGNST@BGREEN/
# /college-football/gametracker/recap/NCAAF_20190907_BGREEN@KSTATE/
#   --> This file is 105.3kB.
# data/games/NCAAF_20190907_BGREEN_KSTATE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190914_LATECH@BGREEN/
# /college-football/gametracker/recap/NCAAF_20190921_BGREEN@KENTST/
# /college-football/gametracker/recap/NCAAF_20191005_BGREEN@ND/
# /college-football/gametracker/recap/NCAAF_20191012_TOLEDO@BGREEN/
#   --> This file is 103.8kB.
# data/games/NCAAF_20191012_TOLEDO_BGREEN.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20191019_CMICH@BGREEN/
#   --> This file is 106.1kB.
# data/games/NCAAF_20191019_CMICH_BGREEN.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190830_WISC@SFLA/
# /college-football/gametracker/recap/NCAAF_20190907_SFLA@GATECH/
# /college-football/gametracker/recap/NCAAF_20190914_SCST@SFLA/
#   --> This file is 105.6kB.
# data/games/NCAAF_20190914_SCST_SFLA.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190928_SMU@SFLA/
# /college-football/gametracker/recap/NCAAF_20191005_SFLA@UCONN/
# /college-football/gametracker/recap/NCAAF_20191012_BYU@SFLA/
# /college-football/gametracker/recap/NCAAF_20191019_SFLA@NAVY/
# /college-football/gametracker/recap/NCAAF_20190831_IDAHO@PSU/
#   --> This file is 114.5kB.
# data/games/NCAAF_20190831_IDAHO_PSU.p size -> 114 kB
# /college-football/gametracker/recap/NCAAF_20190907_BUFF@PSU/
# /college-football/gametracker/recap/NCAAF_20190914_PITT@PSU/
# /college-football/gametracker/recap/NCAAF_20190927_PSU@MD/
# /college-football/gametracker/recap/NCAAF_20191005_PURDUE@PSU/
# /college-football/gametracker/recap/NCAAF_20191012_PSU@IOWA/
#   --> This file is 106.4kB.
# data/games/NCAAF_20191012_PSU_IOWA.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191019_MICH@PSU/
# /college-football/gametracker/recap/NCAAF_20190831_PORTST@ARK/
#   --> This file is 108.4kB.
# data/games/NCAAF_20190831_PORTST_ARK.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190907_ARK@MISS/
# /college-football/gametracker/recap/NCAAF_20190914_COLOST@ARK/
# /college-football/gametracker/recap/NCAAF_20190921_SJST@ARK/
#   --> This file is 106.3kB.
# data/games/NCAAF_20190921_SJST_ARK.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190928_TXAM@ARK/
# /college-football/gametracker/recap/NCAAF_20191012_ARK@UK/
# /college-football/gametracker/recap/NCAAF_20191019_AUBURN@ARK/
# /college-football/gametracker/recap/NCAAF_20190831_MISSST@LALAF/
# /college-football/gametracker/recap/NCAAF_20190907_LIB@LALAF/
# /college-football/gametracker/recap/NCAAF_20190914_TXSO@LALAF/
# /college-football/gametracker/recap/NCAAF_20190921_LALAF@OHIO/
# /college-football/gametracker/recap/NCAAF_20190928_LALAF@GAS/
# /college-football/gametracker/recap/NCAAF_20191009_APLST@LALAF/
# /college-football/gametracker/recap/NCAAF_20191017_LALAF@ARKST/
# /college-football/gametracker/recap/NCAAF_20190831_SC@UNC/
# /college-football/gametracker/recap/NCAAF_20190907_MIAMI@UNC/
#   --> This file is 106.5kB.
# data/games/NCAAF_20190907_MIAMI_UNC.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20190913_UNC@WAKE/
# /college-football/gametracker/recap/NCAAF_20190921_APLST@UNC/
# /college-football/gametracker/recap/NCAAF_20190928_CLEM@UNC/
# /college-football/gametracker/recap/NCAAF_20191005_UNC@GATECH/
# /college-football/gametracker/recap/NCAAF_20191019_UNC@VATECH/
#   --> This file is 114.9kB.
# data/games/NCAAF_20191019_UNC_VATECH.p size -> 115 kB
# /college-football/gametracker/recap/NCAAF_20190829_SDST@MINN/
#   --> This file is 102.3kB.
# data/games/NCAAF_20190829_SDST_MINN.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190907_MINN@FRESNO/
# /college-football/gametracker/recap/NCAAF_20190914_GAS@MINN/
# /college-football/gametracker/recap/NCAAF_20190928_MINN@PURDUE/
# /college-football/gametracker/recap/NCAAF_20191005_ILL@MINN/
# /college-football/gametracker/recap/NCAAF_20191012_NEB@MINN/
#   --> This file is 106.2kB.
# data/games/NCAAF_20191012_NEB_MINN.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20191019_MINN@RUT/
# /college-football/gametracker/recap/NCAAF_20190824_MIAMI@FLA/
# /college-football/gametracker/recap/NCAAF_20190907_MIAMI@UNC/
# /college-football/gametracker/recap/NCAAF_20190914_BTHN@MIAMI/
#   --> This file is 102.2kB.
# data/games/NCAAF_20190914_BTHN_MIAMI.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190921_CMICH@MIAMI/
#   --> This file is 106.5kB.
# data/games/NCAAF_20190921_CMICH_MIAMI.p size -> 107 kB
# /college-football/gametracker/recap/NCAAF_20191005_VATECH@MIAMI/
#   --> This file is 108.9kB.
# data/games/NCAAF_20191005_VATECH_MIAMI.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191011_UVA@MIAMI/
# /college-football/gametracker/recap/NCAAF_20191019_GATECH@MIAMI/
# /college-football/gametracker/recap/NCAAF_20190831_NICHST@KSTATE/
#   --> This file is 104.5kB.
# data/games/NCAAF_20190831_NICHST_KSTATE.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190907_BGREEN@KSTATE/
# /college-football/gametracker/recap/NCAAF_20190914_KSTATE@MISSST/
# /college-football/gametracker/recap/NCAAF_20190928_KSTATE@OKLAST/
# /college-football/gametracker/recap/NCAAF_20191005_BAYLOR@KSTATE/
# /college-football/gametracker/recap/NCAAF_20191019_TCU@KSTATE/
# /college-football/gametracker/recap/NCAAF_20190831_SALA@NEB/
# /college-football/gametracker/recap/NCAAF_20190907_NEB@COLO/
#   --> This file is 110.8kB.
# data/games/NCAAF_20190907_NEB_COLO.p size -> 111 kB
# /college-football/gametracker/recap/NCAAF_20190914_NILL@NEB/
# /college-football/gametracker/recap/NCAAF_20190921_NEB@ILL/
# /college-football/gametracker/recap/NCAAF_20190928_OHIOST@NEB/
# /college-football/gametracker/recap/NCAAF_20191005_NWEST@NEB/
# /college-football/gametracker/recap/NCAAF_20191012_NEB@MINN/
# /college-football/gametracker/recap/NCAAF_20190831_SAMST@NMEX/
#   --> This file is 113.0kB.
# data/games/NCAAF_20190831_SAMST_NMEX.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190914_NMEX@ND/
# /college-football/gametracker/recap/NCAAF_20190921_NMEXST@NMEX/
# /college-football/gametracker/recap/NCAAF_20190928_NMEX@LIB/
# /college-football/gametracker/recap/NCAAF_20191004_NMEX@SJST/
#   --> This file is 109.5kB.
# data/games/NCAAF_20191004_NMEX_SJST.p size -> 109 kB
# /college-football/gametracker/recap/NCAAF_20191011_COLOST@NMEX/
# /college-football/gametracker/recap/NCAAF_20191019_NMEX@WYO/
#   --> This file is 102.9kB.
# data/games/NCAAF_20191019_NMEX_WYO.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190831_MIZZOU@WYO/
# /college-football/gametracker/recap/NCAAF_20190907_WYO@TXSTSM/
# /college-football/gametracker/recap/NCAAF_20190914_IDAHO@WYO/
#   --> This file is 104.4kB.
# data/games/NCAAF_20190914_IDAHO_WYO.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190921_WYO@TULSA/
# /college-football/gametracker/recap/NCAAF_20190928_UNLV@WYO/
# /college-football/gametracker/recap/NCAAF_20191012_WYO@SDGST/
# /college-football/gametracker/recap/NCAAF_20191019_NMEX@WYO/
# /college-football/gametracker/recap/NCAAF_20190830_PURDUE@NEVADA/
# /college-football/gametracker/recap/NCAAF_20190907_NEVADA@OREG/
# /college-football/gametracker/recap/NCAAF_20190914_WBRST@NEVADA/
#   --> This file is 99.0kB.
# data/games/NCAAF_20190914_WBRST_NEVADA.p size -> 99 kB
# /college-football/gametracker/recap/NCAAF_20190921_NEVADA@UTEP/
# /college-football/gametracker/recap/NCAAF_20190928_HAWAII@NEVADA/
# /college-football/gametracker/recap/NCAAF_20191012_SJST@NEVADA/
#   --> This file is 107.9kB.
# data/games/NCAAF_20191012_SJST_NEVADA.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20191019_NEVADA@UTAHST/
# /college-football/gametracker/recap/NCAAF_20190829_FIU@TULANE/
# /college-football/gametracker/recap/NCAAF_20190907_TULANE@AUBURN/
# /college-football/gametracker/recap/NCAAF_20190914_MOST@TULANE/
#   --> This file is 99.6kB.
# data/games/NCAAF_20190914_MOST_TULANE.p size -> 100 kB
# /college-football/gametracker/recap/NCAAF_20190919_HOU@TULANE/
# /college-football/gametracker/recap/NCAAF_20191005_TULANE@ARMY/
# /college-football/gametracker/recap/NCAAF_20191012_UCONN@TULANE/
# /college-football/gametracker/recap/NCAAF_20191019_TULANE@MEMP/
#   --> This file is 106.4kB.
# data/games/NCAAF_20191019_TULANE_MEMP.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190831_MISS@MEMP/
# /college-football/gametracker/recap/NCAAF_20190907_SO@MEMP/
#   --> This file is 102.3kB.
# data/games/NCAAF_20190907_SO_MEMP.p size -> 102 kB
# /college-football/gametracker/recap/NCAAF_20190914_MEMP@SALA/
# /college-football/gametracker/recap/NCAAF_20190926_NAVY@MEMP/
# /college-football/gametracker/recap/NCAAF_20191005_MEMP@LAMON/
# /college-football/gametracker/recap/NCAAF_20191012_MEMP@TEMPLE/
# /college-football/gametracker/recap/NCAAF_20191019_TULANE@MEMP/
# /college-football/gametracker/recap/NCAAF_20190831_LATECH@TEXAS/
# /college-football/gametracker/recap/NCAAF_20190907_LSU@TEXAS/
# /college-football/gametracker/recap/NCAAF_20190914_TEXAS@RICE/
# /college-football/gametracker/recap/NCAAF_20190921_OKLAST@TEXAS/
# /college-football/gametracker/recap/NCAAF_20191005_TEXAS@WVU/
# /college-football/gametracker/recap/NCAAF_20191012_OKLA@TEXAS/
# /college-football/gametracker/recap/NCAAF_20191019_KANSAS@TEXAS/
# /college-football/gametracker/recap/NCAAF_20190831_MIAOH@IOWA/
# /college-football/gametracker/recap/NCAAF_20190907_RUT@IOWA/
# /college-football/gametracker/recap/NCAAF_20190914_IOWA@IOWAST/
#   --> This file is 105.1kB.
# data/games/NCAAF_20190914_IOWA_IOWAST.p size -> 105 kB
# /college-football/gametracker/recap/NCAAF_20190928_MTSU@IOWA/
# /college-football/gametracker/recap/NCAAF_20191005_IOWA@MICH/
# /college-football/gametracker/recap/NCAAF_20191012_PSU@IOWA/
# /college-football/gametracker/recap/NCAAF_20191019_PURDUE@IOWA/
# /college-football/gametracker/recap/NCAAF_20190902_ND@LVILLE/
# /college-football/gametracker/recap/NCAAF_20190907_EKY@LVILLE/
#   --> This file is 101.0kB.
# data/games/NCAAF_20190907_EKY_LVILLE.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20190914_LVILLE@WKY/
# /college-football/gametracker/recap/NCAAF_20190921_LVILLE@FSU/
# /college-football/gametracker/recap/NCAAF_20191005_BC@LVILLE/
# /college-football/gametracker/recap/NCAAF_20191012_LVILLE@WAKE/
# /college-football/gametracker/recap/NCAAF_20191019_CLEM@LVILLE/
# /college-football/gametracker/recap/NCAAF_20190830_COLOST@COLO/
# /college-football/gametracker/recap/NCAAF_20190907_NEB@COLO/
# /college-football/gametracker/recap/NCAAF_20190914_AF@COLO/
# /college-football/gametracker/recap/NCAAF_20190921_COLO@ARIZST/
# /college-football/gametracker/recap/NCAAF_20191005_ARIZ@COLO/
# /college-football/gametracker/recap/NCAAF_20191011_COLO@OREG/
# /college-football/gametracker/recap/NCAAF_20191019_COLO@WASHST/
# /college-football/gametracker/recap/NCAAF_20190831_TOLEDO@UK/
# /college-football/gametracker/recap/NCAAF_20190914_MURYST@TOLEDO/
# /college-football/gametracker/recap/NCAAF_20190921_TOLEDO@COLOST/
# /college-football/gametracker/recap/NCAAF_20190928_BYU@TOLEDO/
# /college-football/gametracker/recap/NCAAF_20191005_WMICH@TOLEDO/
# /college-football/gametracker/recap/NCAAF_20191012_TOLEDO@BGREEN/
# /college-football/gametracker/recap/NCAAF_20191019_TOLEDO@BALLST/
# /college-football/gametracker/recap/NCAAF_20190831_FRESNO@USC/
# /college-football/gametracker/recap/NCAAF_20190907_STNFRD@USC/
# /college-football/gametracker/recap/NCAAF_20190914_USC@BYU/
# /college-football/gametracker/recap/NCAAF_20190920_UTAH@USC/
# /college-football/gametracker/recap/NCAAF_20190928_USC@WASH/
# /college-football/gametracker/recap/NCAAF_20191012_USC@ND/
# /college-football/gametracker/recap/NCAAF_20191019_ARIZ@USC/
# /college-football/gametracker/recap/NCAAF_20190831_NOIOWA@IOWAST/
#   --> This file is 105.9kB.
# data/games/NCAAF_20190831_NOIOWA_IOWAST.p size -> 106 kB
# /college-football/gametracker/recap/NCAAF_20190914_IOWA@IOWAST/
# /college-football/gametracker/recap/NCAAF_20190921_LAMON@IOWAST/
# /college-football/gametracker/recap/NCAAF_20190928_IOWAST@BAYLOR/
# /college-football/gametracker/recap/NCAAF_20191005_TCU@IOWAST/
# /college-football/gametracker/recap/NCAAF_20191012_IOWAST@WVU/
# /college-football/gametracker/recap/NCAAF_20191019_IOWAST@TXTECH/
#   --> This file is 107.9kB.
# data/games/NCAAF_20191019_IOWAST_TXTECH.p size -> 108 kB
# /college-football/gametracker/recap/NCAAF_20190829_ALBANY@CMICH/
# /college-football/gametracker/recap/NCAAF_20190907_CMICH@WISC/
# /college-football/gametracker/recap/NCAAF_20190914_AKRON@CMICH/
# /college-football/gametracker/recap/NCAAF_20190921_CMICH@MIAMI/
# /college-football/gametracker/recap/NCAAF_20190928_CMICH@WMICH/
# /college-football/gametracker/recap/NCAAF_20191005_EMICH@CMICH/
# /college-football/gametracker/recap/NCAAF_20191012_NMEXST@CMICH/
# /college-football/gametracker/recap/NCAAF_20191019_CMICH@BGREEN/
# /college-football/gametracker/recap/NCAAF_20190831_VATECH@BC/
# /college-football/gametracker/recap/NCAAF_20190907_ODU@VATECH/
# /college-football/gametracker/recap/NCAAF_20190914_FUR@VATECH/
#   --> This file is 103.1kB.
# data/games/NCAAF_20190914_FUR_VATECH.p size -> 103 kB
# /college-football/gametracker/recap/NCAAF_20190927_DUKE@VATECH/
# /college-football/gametracker/recap/NCAAF_20191005_VATECH@MIAMI/
# /college-football/gametracker/recap/NCAAF_20191012_RI@VATECH/
#   --> This file is 100.7kB.
# data/games/NCAAF_20191012_RI_VATECH.p size -> 101 kB
# /college-football/gametracker/recap/NCAAF_20191019_UNC@VATECH/
# /college-football/gametracker/recap/NCAAF_20190829_NCO@SJST/
#   --> This file is 104.4kB.
# data/games/NCAAF_20190829_NCO_SJST.p size -> 104 kB
# /college-football/gametracker/recap/NCAAF_20190907_TULSA@SJST/
# /college-football/gametracker/recap/NCAAF_20190921_SJST@ARK/
# /college-football/gametracker/recap/NCAAF_20190927_SJST@AF/
# /college-football/gametracker/recap/NCAAF_20191004_NMEX@SJST/
# /college-football/gametracker/recap/NCAAF_20191012_SJST@NEVADA/
# /college-football/gametracker/recap/NCAAF_20191019_SDGST@SJST/
# /college-football/gametracker/recap/NCAAF_20190831_MTST@TXTECH/
#   --> This file is 112.6kB.
# data/games/NCAAF_20190831_MTST_TXTECH.p size -> 113 kB
# /college-football/gametracker/recap/NCAAF_20190907_UTEP@TXTECH/
# /college-football/gametracker/recap/NCAAF_20190914_TXTECH@ARIZ/
# /college-football/gametracker/recap/NCAAF_20190928_TXTECH@OKLA/
# /college-football/gametracker/recap/NCAAF_20191005_OKLAST@TXTECH/
# /college-football/gametracker/recap/NCAAF_20191012_TXTECH@BAYLOR/
# /college-football/gametracker/recap/NCAAF_20191019_IOWAST@TXTECH/

# %%
from fileUtils import getDirname, getBaseFilename, getBasename

files = findExt("data/games", ".p")
for ifile in files:
    bsdata = getHTML(ifile)
    divs   = bsdata.findAll("div", {"class": "play-by-play-container"})
    for div in divs:
        tdivs = bsdata.findAll("div", {"class": "TableBaseWrapper"})
        for driveNo,tdiv in enumerate(tdivs):
            ## Drive Description
            driveDescription = tdiv.find("div", {"class": "drive-description"})
            driveDesc = None
            if driveDescription is not None:
                driveDesc = driveDescription.text
            print(driveNo,'\t',driveDesc)
                
            ## Drives
            for table in tdiv.find("table", {"class": "TableBase-table"}):
                ths = table.findAll("th")
                trs = table.findAll("tr")
                if len(ths) == 0 and len(trs) == 0:
                    continue
                elif len(ths) == 2 and len(trs) == 1:
                    continue
                else:
                    for playNo,tr in enumerate(trs):
                        tds = tr.findAll("td")
                        
                        ## Summary
                        summaryTD = tds[0]
                        playResult = summaryTD.find("div", {"class": "play-by-play-result"})                        
                        if playResult is not None:
                            playResult = playResult.text
                        
                        ## Play
                        playTD = tds[1]
                        playDownDist = playTD.find("div", {"class": "play-by-play-down-distance"})                        
                        if playDownDist is not None:
                            playDownDist = playDownDist.text
                            
                        removeTag(playTD, 'div')
                        playSummary = None
                        if playTD is not None:
                            playSummary = playTD.text
                        print("  ",playNo,'\t',playResult,'\t',playDownDist,'\t',playSummary)
                        
                        
                        ## Play Result
                
                
            #print(tdiv)
        break
    break
# Out:
# 0 	  - TD (11 plays, 61 yards, 5:03 poss)
#    0 	 Kickoff
# (15:00 - 1st) 17-C.Dicker kicks 48 yards from TEX 35. 22-T.Pledger to OKL 34 for 17 yards (44-T.Owens).
#
#    1 	 +23 YD 	 1 & 10 - OKLA 34
# (15:00 - 1st) 26-K.Brooks pushed ob at TEX 43 for 23 yards (6-J.Mitchell).
#
#    2 	 +4 YD 	 1 & 10 - OKLA 43
# (14:54 - 1st) 26-K.Brooks to TEX 39 for 4 yards (32-M.Roach).
#
#    3 	 Penalty 	 2 & 6 - OKLA 39
# (14:28 - 1st) Penalty on OKL 77-E.Swenson False start 5 yards enforced at TEX 39. No Play.
#
#    4 	 +6 YD 	 2 & 11 - OKLA 44
# (13:54 - 1st) 1-J.Hurts to TEX 38 for 6 yards.
#
#    5 	 +11 YD 	 3 & 5 - OKLA 38
# (13:35 - 1st) 1-J.Hurts to TEX 27 for 11 yards (25-B.Foster40-A.Adeoye).
#
#    6 	 No Gain 	 1 & 10 - OKLA 27
# (12:54 - 1st) 1-J.Hurts to TEX 27 for no gain (49-T.Graham19-B.Jones).
#
#    7 	 +17 YD 	 2 & 10 - OKLA 27
# (12:25 - 1st) 1-J.Hurts complete to 83-N.Basquine. 83-N.Basquine to TEX 10 for 17 yards (15-C.Brown).
#
#    8 	 No Gain 	 1 & 10 - OKLA 10
# (11:44 - 1st) 1-J.Hurts incomplete. Intended for 2-C.Lamb.
#
#    9 	 +1 YD 	 2 & 10 - OKLA 10
# (11:13 - 1st) 1-J.Hurts to TEX 9 for 1 yard (25-B.Foster).
#
#    10 	 +8 YD 	 3 & 9 - OKLA 9
# (11:04 - 1st) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb pushed ob at TEX 1 for 8 yards (15-C.Brown).
#
#    11 	 +1 YD 	 4 & 1 - OKLA 1
# (10:19 - 1st) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb runs 1 yard for a touchdown.
#
#    12 	 PAT Good
# (9:57 - 1st) 47-G.Brkic extra point is good.
#
# 1 	  - Punt (3 plays, -12 yards, 1:13 poss)
#    0 	 Kickoff
# (9:54 - 1st) 47-G.Brkic kicks 64 yards from OKL 35. 6-D.Duvernay to TEX 32 for 31 yards (29-R.Stevenson).
#
#    1 	 -2 YD 	 1 & 10 - TEXAS 32
# (9:54 - 1st) 6-D.Duvernay to TEX 30 for -2 yards (32-D.Turner-Yell).
#
#    2 	 No Gain 	 2 & 12 - TEXAS 30
# (9:47 - 1st) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to TEX 30 for no gain (9-K.Murray).
#
#    3 	 Sack 	 3 & 12 - TEXAS 30
# (9:19 - 1st) 11-S.Ehlinger sacked at TEX 20 for -10 yards (90-N.Gallimore).
#
#    4 	 Punt 	 4 & 22 - TEXAS 20
# (8:41 - 1st) 8-R.Bujcevski punts 36 yards from TEX 20 to OKL 44 fair catch by 2-C.Lamb.
#
# 2 	  - Fumble (5 plays, 70 yards, 1:32 poss)
#    0 	 +17 YD 	 1 & 10 - OKLA 44
# (8:00 - 1st) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb to TEX 39 for 17 yards (19-B.Jones).
#
#    1 	 -1 YD 	 1 & 10 - OKLA 39
# (7:51 - 1st) 1-J.Hurts complete to 26-K.Brooks. 26-K.Brooks to TEX 40 for -1 yard (15-C.Brown).
#
#    2 	 +6 YD 	 2 & 11 - OKLA 40
# (7:30 - 1st) 1-J.Hurts complete to 14-C.Rambo. 14-C.Rambo pushed ob at TEX 34 for 6 yards (5-D.Jamison).
#
#    3 	  	 3 & 5 - OKLA
# (6:54 - 1st) 1-J.Hurts to TEX 13 for 21 yards (4-A.Cook).
#
#    4 	 +27 YD 	 3 & 5 - OKLA 34
# (6:28 - 1st) 1-J.Hurts to TEX 7 FUMBLES (4-A.Cook). 5-D.Jamison to TEX 7 for no gain.
#
# 3 	  - Punt (9 plays, 47 yards, 3:54 poss)
#    0 	 +2 YD 	 1 & 10 - TEXAS 7
# (6:28 - 1st) 26-K.Ingram to TEX 9 for 2 yards (6-T.Brown96-L.Stokes).
#
#    1 	 +9 YD 	 2 & 8 - TEXAS 9
# (6:20 - 1st) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to TEX 18 for 9 yards (32-D.Turner-Yell).
#
#    2 	 No Gain 	 1 & 10 - TEXAS 18
# (5:44 - 1st) 11-S.Ehlinger incomplete. Intended for 26-K.Ingram.
#
#    3 	 +6 YD 	 2 & 10 - TEXAS 18
# (5:28 - 1st) 11-S.Ehlinger to TEX 24 for 6 yards (40-J.Terry).
#
#    4 	 +6 YD 	 3 & 4 - TEXAS 24
# (5:22 - 1st) 11-S.Ehlinger complete to 13-B.Eagles. 13-B.Eagles to TEX 30 for 6 yards (6-T.Brown).
#
#    5 	 +22 YD 	 1 & 10 - TEXAS 30
# (4:47 - 1st) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson to OKL 48 for 22 yards (9-K.Murray).
#
#    6 	 +1 YD 	 1 & 10 - TEXAS 48
# (4:18 - 1st) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to OKL 47 for 1 yard (32-D.Turner-Yell).
#
#    7 	 +3 YD 	 2 & 9 - TEXAS 47
# (3:49 - 1st) 2-R.Johnson to OKL 44 for 3 yards (32-D.Turner-Yell10-P.Fields).
#
#    8 	 -2 YD 	 3 & 6 - TEXAS 44
# (3:12 - 1st) 11-S.Ehlinger to OKL 46 for -2 yards (91-D.Faamatau23-D.White).
#
#    9 	 Punt 	 4 & 8 - TEXAS 46
# (2:34 - 1st) 8-R.Bujcevski punts 41 yards from OKL 46 Downed at the OKL 5.
#
# 4 	  - Interception (11 plays, 5 yards, 1:16 poss)
#    0 	 +3 YD 	 1 & 10 - OKLA 5
# (1:50 - 1st) 1-J.Hurts to OKL 8 for 3 yards (91-J.Chisholm).
#
#    1 	 +14 YD 	 2 & 7 - OKLA 8
# (1:40 - 1st) 26-K.Brooks pushed ob at OKL 22 for 14 yards (40-A.Adeoye).
#
#    2 	 -1 YD 	 1 & 10 - OKLA 22
# (1:05 - 1st) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb to OKL 21 for -1 yard (46-J.Ossai).
#
#    3 	 +7 YD 	 2 & 11 - OKLA 21
# (0:34 - 1st) 1-J.Hurts to OKL 28 for 7 yards (19-B.Jones).
#
#    4 	 +22 YD 	 3 & 4 - OKLA 28
# (15:00 - 2nd) 1-J.Hurts to OKL 50 for 22 yards (99-K.Coburn).
#
#    5 	 +5 YD 	 1 & 10 - OKLA 50
# (14:14 - 2nd) 22-T.Pledger to TEX 45 for 5 yards (40-A.Adeoye99-K.Coburn).
#
#    6 	 +6 YD 	 2 & 5 - OKLA 45
# (13:41 - 2nd) 1-J.Hurts to TEX 39 for 6 yards.
#
#    7 	 +26 YD 	 1 & 10 - OKLA 39
# (13:01 - 2nd) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb to TEX 13 for 26 yards (5-D.Jamison).
#
#    8 	 +2 YD 	 1 & 10 - OKLA 13
# (12:22 - 2nd) 26-K.Brooks to TEX 11 for 2 yards (46-J.Ossai40-A.Adeoye).
#
#    9 	 No Gain 	 2 & 8 - OKLA 11
# (11:55 - 2nd) 1-J.Hurts incomplete. Intended for 2-C.Lamb.
#
#    10 	 Int 	 3 & 8 - OKLA 11
# (11:13 - 2nd) 1-J.Hurts incomplete. Intended for 2-C.Lamb INTERCEPTED by 19-B.Jones at TEX End Zone. 19-B.Jones to TEX 10 for 10 yards (14-C.Rambo).
#
# 5 	  - Punt (7 plays, 6 yards, 3:29 poss)
#    0 	 +2 YD 	 1 & 10 - TEXAS 10
# (11:08 - 2nd) 2-R.Johnson to TEX 12 for 2 yards (35-N.Bonitto).
#
#    1 	 -2 YD 	 2 & 8 - TEXAS 12
# (10:52 - 2nd) 11-S.Ehlinger complete to 2-R.Johnson. 2-R.Johnson to TEX 10 for -2 yards (9-K.Murray).
#
#    2 	 +14 YD 	 3 & 10 - TEXAS 10
# (10:28 - 2nd) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson to TEX 24 for 14 yards (11-P.Motley).
#
#    3 	 No Gain 	 1 & 10 - TEXAS 24
# (9:51 - 2nd) 11-S.Ehlinger incomplete. Intended for 16-J.Smith.
#
#    4 	 -1 YD 	 2 & 10 - TEXAS 24
# (9:10 - 2nd) 11-S.Ehlinger to TEX 23 for -1 yard (11-P.Motley35-N.Bonitto).
#
#    5 	 +3 YD 	 3 & 11 - TEXAS 23
# (9:03 - 2nd) 11-S.Ehlinger scrambles pushed ob at TEX 26 for 3 yards (9-K.Murray).
#
#    6 	 Penalty 	 4 & 8 - TEXAS 26
# (8:26 - 2nd) Penalty on TEX 44-T.Owens False start 5 yards enforced at TEX 26. No Play.
#
#    7 	 Punt 	 4 & 13 - TEXAS 21
# (7:39 - 2nd) 8-R.Bujcevski punts 42 yards from TEX 21. 2-C.Lamb to OKL 42 for 5 yards (39-M.Estell).
#
# 6 	  - Punt (3 plays, 3 yards, 1:09 poss)
#    0 	 -6 YD 	 1 & 10 - OKLA 42
# (7:17 - 2nd) 29-R.Stevenson to OKL 36 for -6 yards (4-A.Cook).
#
#    1 	 +9 YD 	 2 & 16 - OKLA 36
# (7:07 - 2nd) 1-J.Hurts to OKL 45 for 9 yards (36-J.Jones).
#
#    2 	 No Gain 	 3 & 7 - OKLA 45
# (6:31 - 2nd) 1-J.Hurts incomplete. Intended for 2-C.Lamb. Penalty on OKL 84-L.Morris Pass interference declined.
#
#    3 	 Punt 	 4 & 7 - OKLA 45
# (6:08 - 2nd) 46-R.Mundschau punts 21 yards from OKL 45 out of bounds at the TEX 34. Penalty on TEX 50-B.Vaughns Holding 10 yards enforced at TEX 34.
#
# 7 	  - Punt (3 plays, -6 yards, 0:51 poss)
#    0 	 +7 YD 	 1 & 10 - TEXAS 24
# (6:03 - 2nd) 26-K.Ingram to TEX 31 for 7 yards (10-P.Fields).
#
#    1 	 Sack 	 2 & 3 - TEXAS 31
# (5:56 - 2nd) 48-J.Ehlinger to TEX 31 FUMBLES. 11-S.Ehlinger sacked at TEX 25 for -6 yards. Penalty on TEX 11-S.Ehlinger Intentional grounding 0 yards enforced at TEX 25. (35-N.Bonitto).
#
#    2 	 Sack 	 3 & 9 - TEXAS 25
# (5:20 - 2nd) 11-S.Ehlinger sacked at TEX 18 for -7 yards (10-P.Fields).
#
#    3 	 Punt 	 4 & 16 - TEXAS 18
# (5:12 - 2nd) 8-R.Bujcevski punts 37 yards from TEX 18 to OKL 45 fair catch by 2-C.Lamb.
#
# 8 	  - FG (7 plays, 53 yards, 2:14 poss)
#    0 	 +2 YD 	 1 & 10 - OKLA 45
# (4:24 - 2nd) 29-R.Stevenson to OKL 47 for 2 yards.
#
#    1 	 +22 YD 	 2 & 8 - OKLA 47
# (4:17 - 2nd) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb pushed ob at TEX 31 for 22 yards (40-A.Adeoye).
#
#    2 	 +14 YD 	 1 & 10 - OKLA 31
# (3:50 - 2nd) 29-R.Stevenson to TEX 17 for 14 yards (5-D.Jamison25-B.Foster).
#
#    3 	 +13 YD 	 1 & 10 - OKLA 17
# (3:20 - 2nd) 1-J.Hurts scrambles runs ob at TEX 4 for 13 yards.
#
#    4 	 No Gain 	 1 & 4 - OKLA 4
# (2:51 - 2nd) 1-J.Hurts incomplete. Intended for 27-J.Hall.
#
#    5 	 No Gain 	 2 & 4 - OKLA 4
# (2:21 - 2nd) 1-J.Hurts incomplete. Intended for 14-C.Rambo.
#
#    6 	 +2 YD 	 3 & 4 - OKLA 4
# (2:13 - 2nd) 1-J.Hurts to TEX 2 for 2 yards (99-K.Coburn).
#
#    7 	 Field Goal 	 4 & 2 - OKLA 2
# (2:10 - 2nd) 47-G.Brkic 19 yards Field Goal is Good.
#
# 9 	  - Halftime (7 plays, 48 yards, 1:40 poss)
#    0 	 Kickoff
# (1:54 - 2nd) 47-G.Brkic kicks 65 yards from OKL 35. 6-D.Duvernay to TEX 21 for 21 yards (24-B.Asamoah35-N.Bonitto).
#
#    1 	 +18 YD 	 1 & 10 - TEXAS 21
# (1:49 - 2nd) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay pushed ob at TEX 39 for 18 yards (10-P.Fields).
#
#    2 	 +5 YD 	 1 & 10 - TEXAS 39
# (1:44 - 2nd) 11-S.Ehlinger to TEX 44 for 5 yards (40-J.Terry).
#
#    3 	 +7 YD 	 2 & 5 - TEXAS 44
# (1:38 - 2nd) 6-D.Duvernay to OKL 49 for 7 yards (4-J.Davis23-D.White).
#
#    4 	 Sack 	 1 & 10 - TEXAS 49
# (1:08 - 2nd) 11-S.Ehlinger sacked at OKL 50 for -1 yard (7-R.Perkins).
#
#    5 	 +2 YD 	 2 & 11 - TEXAS 50
# (0:49 - 2nd) 11-S.Ehlinger pushed ob at OKL 48 for 2 yards (44-B.Radley-Hiles). Penalty on OKL 44-B.Radley-Hiles Holding 10 yards enforced at OKL 48.
#
#    6 	 +3 YD 	 1 & 10 - TEXAS 38
# (0:26 - 2nd) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson runs ob at OKL 35 for 3 yards.
#
#    7 	 +4 YD 	 2 & 7 - TEXAS 35
# (0:18 - 2nd) 11-S.Ehlinger scrambles runs ob at OKL 31 for 4 yards.
#
#    8 	 Field Goal 	 3 & 3 - TEXAS 31
# (0:14 - 2nd) 17-C.Dicker 49 yards Field Goal is Good.
#
# 10 	  - Punt (6 plays, 3 yards, 0:00 poss)
#    0 	 Kickoff
# (0:06 - 2nd) 47-G.Brkic kicks 65 yards from OKL 35. 6-D.Duvernay to TEX 13 for 13 yards (29-R.Stevenson).
#
#    1 	 No Gain 	 1 & 10 - TEXAS 13
# (15:00 - 3rd) 11-S.Ehlinger incomplete. Intended for 13-B.Eagles.
#
#    2 	 +3 YD 	 2 & 10 - TEXAS 13
# (14:54 - 3rd) 11-S.Ehlinger complete to 26-K.Ingram. 26-K.Ingram to TEX 16 for 3 yards (32-D.Turner-Yell).
#
#    3 	 +11 YD 	 3 & 7 - TEXAS 16
# (14:47 - 3rd) 11-S.Ehlinger scrambles to TEX 27 for 11 yards (32-D.Turner-Yell).
#
#    4 	 -1 YD 	 1 & 10 - TEXAS 27
# (14:06 - 3rd) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to TEX 26 for -1 yard (25-J.Broiles).
#
#    5 	 No Gain 	 2 & 11 - TEXAS 26
# (13:46 - 3rd) 11-S.Ehlinger incomplete. Intended for 13-B.Eagles.
#
#    6 	 Sack 	 3 & 11 - TEXAS 26
# (13:17 - 3rd) 11-S.Ehlinger sacked at TEX 16 for -10 yards (9-K.Murray).
#
#    7 	 Punt 	 4 & 21 - TEXAS 16
# (13:13 - 3rd) 8-R.Bujcevski punts 47 yards from TEX 16. 2-C.Lamb to OKL 35 for -2 yards (1-J.Burt).
#
# 11 	  - Punt (3 plays, 3 yards, 0:57 poss)
#    0 	 +3 YD 	 1 & 10 - OKLA 35
# (12:42 - 3rd) 29-R.Stevenson to OKL 38 for 3 yards (49-T.Graham).
#
#    1 	 No Gain 	 2 & 7 - OKLA 38
# (12:31 - 3rd) 1-J.Hurts incomplete. Intended for 4-T.Sermon.
#
#    2 	 No Gain 	 3 & 7 - OKLA 38
# (11:54 - 3rd) 1-J.Hurts incomplete. Intended for 83-N.Basquine.
#
#    3 	 Punt 	 4 & 7 - OKLA 38
# (11:45 - 3rd) 46-R.Mundschau punts 55 yards from OKL 38 Downed at the TEX 7.
#
# 12 	  - TD (7 plays, 93 yards, 2:46 poss)
#    0 	 +2 YD 	 1 & 10 - TEXAS 7
# (11:41 - 3rd) 11-S.Ehlinger to TEX 9 for 2 yards (7-R.Perkins23-D.White).
#
#    1 	 +19 YD 	 2 & 8 - TEXAS 9
# (11:28 - 3rd) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson to TEX 28 for 19 yards (4-J.Davis).
#
#    2 	 +2 YD 	 1 & 10 - TEXAS 28
# (10:53 - 3rd) 2-R.Johnson to TEX 30 for 2 yards (40-J.Terry).
#
#    3 	 No Gain 	 2 & 8 - TEXAS 30
# (10:40 - 3rd) 6-D.Duvernay to TEX 30 for no gain (10-P.Fields4-J.Davis).
#
#    4 	 +9 YD 	 3 & 8 - TEXAS 30
# (10:12 - 3rd) 11-S.Ehlinger complete to 2-R.Johnson. 2-R.Johnson to TEX 39 for 9 yards (6-T.Brown).
#
#    5 	 +57 YD 	 1 & 10 - TEXAS 39
# (9:30 - 3rd) 2-R.Johnson pushed ob at OKL 4 for 57 yards (32-D.Turner-Yell).
#
#    6 	 +4 YD 	 1 & 4 - TEXAS 4
# (9:14 - 3rd) 2-R.Johnson runs 4 yards for a touchdown.
#
#    7 	 PAT Good
# (8:55 - 3rd) 17-C.Dicker extra point is good.
#
# 13 	  - TD (3 plays, 75 yards, 0:48 poss)
#    0 	 Kickoff
# (8:48 - 3rd) 17-C.Dicker kicks 65 yards from TEX 35 to OKL End Zone. touchback.
#
#    1 	 +9 YD 	 1 & 10 - OKLA 25
# (8:48 - 3rd) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb to OKL 34 for 9 yards (32-M.Roach). Penalty on TEX 32-M.Roach Personal Foul 15 yards enforced at OKL 34.
#
#    2 	 No Gain 	 1 & 10 - OKLA 49
# (8:48 - 3rd) 29-R.Stevenson to OKL 49 for no gain (99-K.Coburn).
#
#    3 	 +51 YD 	 2 & 10 - OKLA 49
# (8:41 - 3rd) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb runs 51 yards for a touchdown.
#
#    4 	 PAT Good
# (8:00 - 3rd) 47-G.Brkic extra point is good.
#
# 14 	  - Punt (5 plays, -6 yards, 0:12 poss)
#    0 	 Kickoff
# (7:45 - 3rd) 47-G.Brkic kicks 60 yards from OKL 35 to the TEX 5 downed by 6-D.Duvernay.
#
#    1 	 No Gain 	 1 & 10 - TEXAS 5
# (7:45 - 3rd) 11-S.Ehlinger incomplete. Intended for 9-C.Johnson.
#
#    2 	 Penalty 	 2 & 10 - TEXAS 5
# (7:45 - 3rd) Penalty on TEX 80-C.Brewer False start 2 yards enforced at TEX 5. No Play.
#
#    3 	 Penalty 	 2 & 12 - TEXAS 3
# (7:40 - 3rd) Team penalty on TEX False start 2 yards enforced at TEX 3. No Play.
#
#    4 	 No Gain 	 2 & 14 - TEXAS 1
# (7:40 - 3rd) 11-S.Ehlinger incomplete. Intended for 13-B.Eagles.
#
#    5 	 +2 YD 	 3 & 14 - TEXAS 1
# (7:40 - 3rd) 11-S.Ehlinger to TEX 3 for 2 yards (7-R.Perkins).
#
#    6 	 Punt 	 4 & 12 - TEXAS 3
# (7:33 - 3rd) 8-R.Bujcevski punts 38 yards from TEX 3. 2-C.Lamb to TEX 38 for 3 yards (50-B.Vaughns).
#
# 15 	  - FG (5 plays, 21 yards, 2:02 poss)
#    0 	 +7 YD 	 1 & 10 - OKLA 38
# (6:58 - 3rd) 1-J.Hurts complete to 14-C.Rambo. 14-C.Rambo pushed ob at TEX 31 for 7 yards (15-C.Brown19-B.Jones).
#
#    1 	 +10 YD 	 2 & 3 - OKLA 31
# (6:48 - 3rd) 1-J.Hurts complete to 14-C.Rambo. 14-C.Rambo pushed ob at TEX 21 for 10 yards (5-D.Jamison40-A.Adeoye).
#
#    2 	 +4 YD 	 1 & 10 - OKLA 21
# (6:21 - 3rd) 2-C.Lamb to TEX 17 for 4 yards (40-A.Adeoye).
#
#    3 	 No Gain 	 2 & 6 - OKLA 17
# (5:47 - 3rd) 1-J.Hurts incomplete. Intended for 81-B.Willis.
#
#    4 	 No Gain 	 3 & 6 - OKLA 17
# (5:01 - 3rd) 1-J.Hurts incomplete. Intended for 81-B.Willis.
#
#    5 	 Field Goal 	 4 & 6 - OKLA 17
# (4:56 - 3rd) 47-G.Brkic 34 yards Field Goal is Good.
#
# 16 	  - Punt (3 plays, -8 yards, 1:38 poss)
#    0 	 Kickoff
# (4:48 - 3rd) 47-G.Brkic kicks 63 yards from OKL 35. 6-D.Duvernay to TEX 16 for 14 yards (8-T.Bridges).
#
#    1 	 Sack 	 1 & 10 - TEXAS 16
# (4:44 - 3rd) 11-S.Ehlinger sacked at TEX 11 for -5 yards (31-J.Redmond).
#
#    2 	 -3 YD 	 2 & 15 - TEXAS 11
# (4:38 - 3rd) 11-S.Ehlinger complete to 26-K.Ingram. 26-K.Ingram to TEX 8 for -3 yards (24-B.Asamoah).
#
#    3 	 No Gain 	 3 & 18 - TEXAS 8
# (3:55 - 3rd) 11-S.Ehlinger incomplete. Intended for 85-M.Epps.
#
#    4 	 Punt 	 4 & 18 - TEXAS 8
# (3:10 - 3rd) 8-R.Bujcevski punts 40 yards from TEX 8 out of bounds at the TEX 48.
#
# 17 	  - Downs (4 plays, 9 yards, 0:47 poss)
#    0 	 -2 YD 	 1 & 10 - OKLA 48
# (3:05 - 3rd) 26-K.Brooks to TEX 50 for -2 yards (49-T.Graham).
#
#    1 	 No Gain 	 2 & 12 - OKLA 50
# (2:59 - 3rd) 1-J.Hurts incomplete. Intended for 84-L.Morris.
#
#    2 	 +11 YD 	 3 & 12 - OKLA 50
# (2:25 - 3rd) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb to TEX 39 for 11 yards (19-B.Jones).
#
#    3 	 No Gain 	 4 & 1 - OKLA 39
# (2:18 - 3rd) 1-J.Hurts incomplete. Intended for 2-C.Lamb.
#
# 18 	  - TD (8 plays, 55 yards, 1:33 poss)
#    0 	 +23 YD 	 1 & 10 - TEXAS 40
# (1:33 - 3rd) 2-R.Johnson to OKL 37 for 23 yards (32-D.Turner-Yell).
#
#    1 	 +3 YD 	 1 & 10 - TEXAS 37
# (1:30 - 3rd) 2-R.Johnson to OKL 34 for 3 yards (23-D.White).
#
#    2 	 +12 YD 	 2 & 7 - TEXAS 34
# (1:12 - 3rd) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson to OKL 22 for 12 yards.
#
#    3 	 +1 YD 	 1 & 10 - TEXAS 22
# (0:55 - 3rd) 2-R.Johnson to OKL 21 for 1 yard (23-D.White).
#
#    4 	 Penalty 	 2 & 9 - TEXAS 21
# (0:40 - 3rd) 11-S.Ehlinger incomplete. Intended for 9-C.Johnson. Penalty on OKL 6-T.Brown Holding 10 yards enforced at OKL 21. No Play.
#
#    5 	 Penalty 	 1 & 10 - TEXAS 11
# (0:09 - 3rd) Penalty on TEX 9-C.Johnson False start 5 yards enforced at OKL 11. No Play.
#
#    6 	 Penalty 	 1 & 15 - TEXAS 16
# (0:04 - 3rd) 11-S.Ehlinger incomplete. Intended for 9-C.Johnson. Penalty on OKL 6-T.Brown Pass interference 14 yards enforced at OKL 16. No Play.
#
#    7 	 +2 YD 	 1 & 2 - TEXAS 2
# (0:04 - 3rd) 11-S.Ehlinger runs 2 yards for a touchdown.
#
#    8 	 PAT Good
# (0:00 - 3rd) 17-C.Dicker extra point is good.
#
# 19 	  - TD (6 plays, 75 yards, 0:00 poss)
#    0 	 Kickoff
# (0:00 - 3rd) 17-C.Dicker kicks 65 yards from TEX 35 to OKL End Zone. touchback.
#
#    1 	 +25 YD 	 1 & 10 - OKLA 25
# (15:00 - 4th) 1-J.Hurts complete to 81-B.Willis. 81-B.Willis to OKL 50 for 25 yards (15-C.Brown).
#
#    2 	 +9 YD 	 1 & 10 - OKLA 50
# (15:00 - 4th) 1-J.Hurts scrambles to TEX 41 for 9 yards.
#
#    3 	 +2 YD 	 2 & 1 - OKLA 41
# (14:24 - 4th) 1-J.Hurts to TEX 39 for 2 yards (6-J.Mitchell).
#
#    4 	 +8 YD 	 1 & 10 - OKLA 39
# (13:51 - 4th) 26-K.Brooks to TEX 31 for 8 yards (46-J.Ossai).
#
#    5 	 +4 YD 	 2 & 2 - OKLA 31
# (13:16 - 4th) 26-K.Brooks to TEX 27 for 4 yards (46-J.Ossai6-J.Mitchell).
#
#    6 	 +27 YD 	 1 & 10 - OKLA 27
# (12:38 - 4th) 1-J.Hurts complete to 2-C.Lamb. 2-C.Lamb runs 27 yards for a touchdown.
#
#    7 	 PAT Good
# (12:07 - 4th) 47-G.Brkic extra point is good.
#
# 20 	  - FG (14 plays, 61 yards, 4:54 poss)
#    0 	 Kickoff
# (11:56 - 4th) 47-G.Brkic kicks 65 yards from OKL 35 to TEX End Zone. touchback.
#
#    1 	 Sack 	 1 & 10 - TEXAS 25
# (11:56 - 4th) 11-S.Ehlinger sacked at TEX 17 for -8 yards (97-M.Overton).
#
#    2 	 +11 YD 	 2 & 18 - TEXAS 17
# (11:56 - 4th) 11-S.Ehlinger complete to 2-R.Johnson. 2-R.Johnson to TEX 28 for 11 yards (29-J.Perkins).
#
#    3 	 +12 YD 	 3 & 7 - TEXAS 28
# (11:16 - 4th) 11-S.Ehlinger complete to 9-C.Johnson. 9-C.Johnson to TEX 40 for 12 yards (10-P.Fields6-T.Brown).
#
#    4 	 No Gain 	 1 & 10 - TEXAS 40
# (10:34 - 4th) 11-S.Ehlinger incomplete. Intended for 85-M.Epps.
#
#    5 	 +12 YD 	 2 & 10 - TEXAS 40
# (10:15 - 4th) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to OKL 48 for 12 yards (10-P.Fields).
#
#    6 	 +6 YD 	 1 & 10 - TEXAS 48
# (10:10 - 4th) 11-S.Ehlinger complete to 85-M.Epps. 85-M.Epps to OKL 42 for 6 yards (6-T.Brown).
#
#    7 	 Penalty 	 2 & 4 - TEXAS 42
# (10:00 - 4th) 2-R.Johnson to OKL 40 for 2 yards (44-B.Radley-Hiles). Penalty on TEX 68-D.Kerstetter Illegal formation 5 yards enforced at OKL 42. No Play.
#
#    8 	 +10 YD 	 2 & 9 - TEXAS 47
# (9:41 - 4th) 11-S.Ehlinger complete to 85-M.Epps. 85-M.Epps to OKL 37 for 10 yards (4-J.Davis).
#
#    9 	 Penalty 	 1 & 10 - TEXAS 37
# (9:23 - 4th) 11-S.Ehlinger incomplete. Intended for 6-D.Duvernay. Penalty on OKL 10-P.Fields Pass interference 15 yards enforced at OKL 37. No Play.
#
#    10 	 No Gain 	 1 & 10 - TEXAS 22
# (8:48 - 4th) 11-S.Ehlinger incomplete. Intended for 1-J.Burt.
#
#    11 	 +10 YD 	 2 & 10 - TEXAS 22
# (8:41 - 4th) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay pushed ob at OKL 12 for 10 yards (32-D.Turner-Yell).
#
#    12 	 Sack 	 1 & 10 - TEXAS 12
# (8:36 - 4th) 11-S.Ehlinger sacked at OKL 15 for -3 yards (90-N.Gallimore).
#
#    13 	 +1 YD 	 2 & 13 - TEXAS 15
# (8:23 - 4th) 11-S.Ehlinger to OKL 14 for 1 yard (90-N.Gallimore35-N.Bonitto).
#
#    14 	 No Gain 	 3 & 12 - TEXAS 14
# (7:44 - 4th) 11-S.Ehlinger incomplete. Intended for 13-B.Eagles.
#
#    15 	 Field Goal 	 4 & 12 - TEXAS 14
# (7:02 - 4th) 17-C.Dicker 32 yards Field Goal is Good.
#
# 21 	  - TD (5 plays, 75 yards, 2:35 poss)
#    0 	 Kickoff
# (6:57 - 4th) 17-C.Dicker kicks 65 yards from TEX 35 to OKL End Zone. touchback.
#
#    1 	 +42 YD 	 1 & 10 - OKLA 25
# (6:53 - 4th) 26-K.Brooks to TEX 33 for 42 yards (46-J.Ossai).
#
#    2 	 +24 YD 	 1 & 10 - OKLA 33
# (6:53 - 4th) 29-R.Stevenson to TEX 9 for 24 yards (40-A.Adeoye).
#
#    3 	 +6 YD 	 1 & 9 - OKLA 9
# (6:12 - 4th) 26-K.Brooks to TEX 3 for 6 yards (46-J.Ossai).
#
#    4 	 No Gain 	 2 & 3 - OKLA 3
# (5:56 - 4th) 1-J.Hurts to TEX 3 for no gain (46-J.Ossai96-T.Bennett).
#
#    5 	 +3 YD 	 3 & 3 - OKLA 3
# (5:09 - 4th) 1-J.Hurts runs 3 yards for a touchdown.
#
#    6 	 PAT Good
# (4:22 - 4th) 47-G.Brkic extra point is good.
#
# 22 	  - TD (11 plays, 75 yards, 2:25 poss)
#    0 	 Kickoff
# (4:19 - 4th) 47-G.Brkic kicks 65 yards from OKL 35 to TEX End Zone. touchback.
#
#    1 	 +5 YD 	 1 & 10 - TEXAS 25
# (4:19 - 4th) 11-S.Ehlinger scrambles to TEX 30 for 5 yards (90-N.Gallimore7-R.Perkins).
#
#    2 	 No Gain 	 2 & 5 - TEXAS 30
# (4:19 - 4th) 11-S.Ehlinger incomplete. Intended for 2-R.Johnson.
#
#    3 	 +6 YD 	 3 & 5 - TEXAS 30
# (3:49 - 4th) 11-S.Ehlinger complete to 13-B.Eagles. 13-B.Eagles to TEX 36 for 6 yards (6-T.Brown).
#
#    4 	 Penalty 	 1 & 10 - TEXAS 36
# (3:43 - 4th) 11-S.Ehlinger incomplete. Intended for 85-M.Epps. Penalty on OKL 55-K.Mann Illegal use of hands 15 yards enforced at TEX 36. No Play.
#
#    5 	 +10 YD 	 1 & 10 - TEXAS 49
# (3:26 - 4th) 11-S.Ehlinger complete to 80-C.Brewer. 80-C.Brewer to OKL 39 for 10 yards (32-D.Turner-Yell).
#
#    6 	 +5 YD 	 2 & 28 - TEXAS 39
# (3:21 - 4th) 11-S.Ehlinger complete to 2-R.Johnson. 2-R.Johnson to OKL 34 for 5 yards (44-B.Radley-Hiles).
#
#    7 	 Sack 	 2 & 5 - TEXAS 34
# (3:11 - 4th) 11-S.Ehlinger sacked at OKL 37 for -3 yards (33-M.Stripling).
#
#    8 	 +5 YD 	 3 & 8 - TEXAS 37
# (2:57 - 4th) 11-S.Ehlinger complete to 6-D.Duvernay. 6-D.Duvernay to OKL 32 for 5 yards (4-J.Davis). Penalty on OKL 9-K.Murray Personal Foul 15 yards enforced at OKL 32.
#
#    9 	 No Gain 	 1 & 10 - TEXAS 17
# (2:39 - 4th) 11-S.Ehlinger incomplete. Intended for 85-M.Epps.
#
#    10 	 +13 YD 	 2 & 10 - TEXAS 17
# (2:16 - 4th) 11-S.Ehlinger complete to 85-M.Epps. 85-M.Epps to OKL 4 for 13 yards (6-T.Brown).
#
#    11 	 +4 YD 	 1 & 4 - TEXAS 4
# (2:09 - 4th) 11-S.Ehlinger runs 4 yards for a touchdown.
#
#    12 	 PAT Good
# (1:54 - 4th) 17-C.Dicker extra point is good.
#
# 23 	  - End of Game (5 plays, 8 yards, 0:51 poss)
#    0 	 Kickoff
# (1:49 - 4th) 17-C.Dicker kicks 11 yards from TEX 35 out of bounds at the TEX 46.
#
#    1 	 +4 YD 	 1 & 10 - OKLA 46
# (1:49 - 4th) 26-K.Brooks to TEX 42 for 4 yards (46-J.Ossai).
#
#    2 	 +10 YD 	 2 & 6 - OKLA 42
# (1:49 - 4th) 1-J.Hurts to TEX 32 for 10 yards (46-J.Ossai).
#
#    3 	 -2 YD 	 1 & 10 - OKLA 32
# (1:45 - 4th) 1-J.Hurts kneels at TEX 34 for -2 yards.
#
#    4 	 -2 YD 	 2 & 12 - OKLA 34
# (1:38 - 4th) 1-J.Hurts kneels at TEX 36 for -2 yards.
#
#    5 	 -2 YD 	 3 & 14 - OKLA 36
# (0:58 - 4th) 1-J.Hurts kneels at TEX 38 for -2 yards.

# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

## Python Version
import sys
print("Python: {0}".format(sys.version))

from os.path import join
from fsUtils import mkSubDir, setFile, isFile, removeFile, isDir
from ioUtils import getFile, saveFile
from timeUtils import clock, elapsed
from fileUtils import getBaseFilename, getBasename, getDirname
from webUtils import getWebData, getHTML
from timeUtils import printDateTime, getDateTime, addMonths
from searchUtils import findExt
from time import sleep
from random import random
import sys
import re
from datetime import timedelta

from espngames import output, espn
from espngames import game, team, season
from espngames import historical

import datetime as dt
start = dt.datetime.now()

print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:07:29)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2019-04-07 15:37:52.646904

# %%
from os.path import join
from fsUtils import mkSubDir, setFile, isFile, removeFile, isDir
from ioUtils import getFile, saveFile
from timeUtils import clock, elapsed
from fileUtils import getBaseFilename, getBasename, getDirname
from webUtils import getWebData, getHTML
from timeUtils import printDateTime, getDateTime, addMonths
from searchUtils import findExt
from time import sleep
from random import random
import sys
import re
from datetime import timedelta



class output:
    def __init__(self):
        self.name   = "output"
        self.dirval = "/Volumes/Blue/Football"
        if not isDir(self.dirval):
            self.dirval = "/Users/tgadfort/Documents/football"


        
    def getSaveDir(self):
        return self.dirval

    
class espn:
    def __init__(self):
        self.name = "espn"
        self.baseurl = "http://www.espn.com"
        
    def getBase(self):
        return self.baseurl


############################################################################################################
# Game Class
############################################################################################################
class game:
    def __init__(self, gameID, date, teamA, teamB, teamAResult, teamBResult, teamAScore, teamBScore, location, extra={}):
        self.gameID = gameID
        self.date   = date
        self.teamA  = teamA
        self.teamB  = teamB
        self.teamAScore  = teamAScore
        self.teamBScore  = teamBScore
        self.teamAResult  = teamAResult
        self.teamBResult  = teamBResult
        self.location = location
        
        self.OT   = extra.get('OT')
        self.Bowl = extra.get('Bowl')

    def getWinner(self):
        if self.teamAScore > self.teamBScore:
            return self.teamA
        elif self.teamAScore < self.teamBScore:
            return self.teamB
        else:
            return "T"

        
    def getGame(self):
        retval = {"GameID": self.gameID}

        
        
############################################################################################################
# Team Class
############################################################################################################
class team:
    def __init__(self, year, teamName, teamMascot, teamID):
        self.year       = year
        self.teamName   = teamName
        self.teamMascot = teamMascot
        self.teamID     = teamID
        self.games      = []

        
    def getTeamID(self):
        return self.teamID
    
        
    def addGame(self, game):
        result = game.teamAResult
        self.games.append({"Result": result, "Game": game})

            
    def setStatistics(self):
        wins   = sum([x["Result"] == "W" for x in self.games])
        losses = sum([x["Result"] == "L" for x in self.games])
        ties   = sum([x["Result"] == "T" for x in self.games])
        ngames = len(self.games)
        if ngames != wins+losses+ties:
            raise ValueError("The sum of wins, losses, and ties does not match total number of games!")
        self.wins   = wins
        self.losses = losses
        self.ties   = ties
        self.ngames = ngames

        
    def summary(self):
        print("{0: <6}{1: <50}{2: <5}{3: <5}{4: <5}{5: <5}".format(self.year, self.teamName, 
                                                                   self.wins, self.losses, self.ties, self.ngames))
        
        
    def getGames(self):
        return self.games
        
        
############################################################################################################
# Season Class
############################################################################################################
class season:
    def __init__(self, year):
        self.year  = year
        self.teams = {}
        self.games = {}
        
    def getYear(self):
        return self.year
    
    def addTeam(self, team):
        teamID = team.getTeamID()
        self.teams[teamID] = team



############################################################################################################
# Historical Class
############################################################################################################
class historical(espn, output):
    def __init__(self):
        self.name = "historical"
        espn.__init__(self)
        output.__init__(self)
        
        ## 2015
        self.noGameData2003 = ['232350023', '232400195', '232400254', '232402006', '232402050', '232412439', '232420021', '232420062', '232420167', '232420235', '232420248', '232420276', '232422005', '232422426', '232422440', '232422751', '232442132', '232470005', '232490068', '232490309', '232490349', '232492638', '232492649', '232492655', '232550276', '232560005', '232560036', '232560070', '232560167', '232560189', '232560202', '232560309', '232562005', '232562084', '232562572', '232562638', '232610023', '232630021', '232630036', '232630097', '232630202', '232630278', '232630349', '232632005', '232632006', '232632084', '232632426', '232632439', '232700036', '232700062', '232700068', '232700149', '232700167', '232700193', '232700235', '232700252', '232700278', '232700349', '232702084', '232702440', '232702638', '232702653', '232730151', '232770021', '232770036', '232770041', '232770058', '232770166', '232770167', '232770193', '232770202', '232770235', '232770242', '232772132', '232772309', '232772348', '232772426', '232772440', '232772567', '232820252', '232840005', '232840023', '232840062', '232840068', '232840070', '232840097', '232840254', '232840276', '232840328', '232842005', '232842006', '232842638', '232842655', '232890036', '232900097', '232910021', '232910202', '232910242', '232910248', '232910249', '232910349', '232912006', '232912084', '232912309', '232912348', '232912439', '232912567', '232912751', '232980021', '232980062', '232980068', '232980151', '232980202', '232980278', '232980328', '232982050', '232982084', '232982132', '232982426', '232982439', '232982440', '232982572', '232982655', '233040252', '233050005', '233050023', '233050166', '233050167', '233050235', '233050242', '233050276', '233052005', '233052426', '233052567', '233052572', '233052638', '233052649', '233052751', '233110167', '233120005', '233120087', '233120151', '233120195', '233120242', '233120248', '233122005', '233122032', '233122132', '233122348', '233122439', '233122440', '233122638', '233190036', '233190087', '233190097', '233190167', '233190202', '233190249', '233190254', '233190278', '233190328', '233190349', '233192006', '233192440', '233192567', '233192572', '233260021', '233260023', '233260058', '233260062', '233260070', '233260097', '233260235', '233260242', '233260252', '233262309', '233262426', '233262439', '233262655', '233262751', '233290166', '233320276', '233322132', '233330151', '233330154', '233330235', '233330248', '233332348', '233332638', '233332751', '233402426']
        self.noGameData2003 += ['232352306']
        self.noGameData2004 = ['242480068', '242480195', '242480242', '242480252', '242480276', '242482751', '242550058', '242550189', '242550235', '242550349', '242552005', '242552006', '242552426', '242552628', '242620023', '242620166', '242620202', '242620242', '242620248', '242622439', '242622440', '242690005', '242690021', '242690036', '242690166', '242690195', '242692567', '242692655', '242730276', '242742005', '242760023', '242760036', '242760058', '242760062', '242760235', '242760249', '242760349', '242762084', '242762132', '242762439', '242762649', '242812572', '242820252', '242830062', '242830195', '242830242', '242830278', '242830328', '242830349', '242832005', '242832006', '242832116', '242890005', '242900058', '242900189', '242900235', '242900252', '242902032', '242902116', '242902426', '242902439', '242902440', '242902567', '242902649', '242960036', '242970062', '242970195', '242970249', '242970276', '242972005', '242972006', '242972132', '242972393', '242972426', '242972440', '242972572', '242972628', '242972649', '242972655', '243040023', '243040036', '243040189', '243040202', '243040248', '243040276', '243040278', '243042132', '243042393', '243042426', '243042751', '243102006', '243110062', '243110070', '243110189', '243110242', '243110252', '243110349', '243112116', '243112439', '243112440', '243112655', '243142459', '243162032', '243170278', '243180005', '243180036', '243180058', '243180189', '243180195', '243180249', '243180252', '243182005', '243182050', '243182084', '243182567', '243182655', '243232032', '243250021', '243250062', '243250151', '243250167', '243250202', '243250276', '243250278', '243250349', '243252005', '243252132', '243252628', '243282116', '243282649', '243320023', '243322572', '243322628', '243340242', '243392426']
        self.noGameData2005 = ['252460008', '252460023', '252460066', '252460204', '252460258', '252462032', '252462567', '252530008', '252530084', '252530096', '252530239', '252600024', '252600025', '252600154', '252600264', '252600265', '252602005', '252670070', '252670238', '252672306', '252672567', '252740023', '252740062', '252740070', '252740204', '252770249', '252810008', '252810166', '252810328', '252812348', '252812440', '252880062', '252880068', '252880278', '252882440', '252950023', '252950154', '252952306', '253020068', '253020096', '253020204', '253020252', '253022306', '253022348', '253090068', '253090328', '253092440', '253160062', '253160070', '253160166', '253160238', '253160349', '253162032', '253230008', '253230023', '253230068', '253230152', '253230328', '253230349', '253232306', '253232426', '253232439', '253300023', '253300166', '253300249', '253302348']
        self.noGameData2006 = ['262440278', '262450084', '262450152', '262450264', '262452306', '262452509', '262520008', '262520059', '262520096', '262520239', '262520252', '262520258', '262522306', '262590070', '262590166', '262590258', '262590264', '262590265', '262590333', '262592348', '262660024', '262660145', '262660238', '262660239', '262660252', '262730096', '262730204', '262730238', '262730239', '262730328', '262800070', '262800328', '262870024', '262870265', '262870278', '262942032', '262942348', '262942440', '263010023', '263012306', '263012440', '263080070', '263080166', '263080204', '263080249', '263080265', '263080328', '263082393', '263082653', '263150062', '263150096', '263150264', '263150278', '263150309', '263152032', '263152226', '263152229', '263152440', '263220062', '263220096', '263220249', '263220276', '263220278', '263222348', '263222653', '263282348', '263290070', '263290145', '263290309', '263290328', '263292393', '263292433', '263360023', '263360166', '263360309', '263362229']
        self.noGameData2007 = ['272440009', '272440058', '272440150', '272440153', '272440195', '272440238', '272440242', '272440245', '272442226', '272442579', '272510012', '272510070', '272510167', '272510197', '272510218', '272510265', '272512567', '272580202', '272580204', '272580235', '272582032', '272650009', '272650021', '272650070', '272650195', '272650248', '272650249', '272652084', '272652638', '272702032', '272720008', '272720195', '272720197', '272720202', '272720248', '272790150', '272790218', '272792084', '272792309', '272792638', '272860005', '272860024', '272860036', '272860193', '272862032', '272862084', '272930005', '272930197', '272930218', '272930242', '273002084', '273002638', '273070005', '273070070', '273070145', '273070150', '273070193', '273070236', '273070242', '273072032', '273072633', '273140005', '273140167', '273140202', '273140276', '273142459', '273142567', '273210036', '273210098', '273210218', '273210242', '273210248', '273210333', '273212084', '273212348', '273212567', '273212638', '273280021', '273280070', '273280167', '273280242', '273280248', '273280276', '273282229', '273282459', '273352653']
        self.noGameData2008 = ['282430005', '282430012', '282430084', '282500012', '282500036', '282500070', '282500183', '282502032', '282570248', '282572032', '282642655', '282710218', '282712649', '282780166', '282782649', '282850021', '282990070', '282990249', '282992649', '283060258', '283062638', '283132393', '283250059', '283262649', '283270218', '283330218', '283412229']
        self.noGameData2009 = ['292460218', '292480193', '292480238', '292550249', '292622348', '292760021', '292762084', '292830218', '292830235', '292830265', '292832084', '292900195', '292970193', '293042638', '293180235', '293250023', '293312006', '293392348']        
        self.noGameData2010 = ['302452309', '302470103', '302472199', '302540077', '302540142', '302612638', 
                               '302680077', '302680183', '302820195', '302820249', '302890098', '302890249',
                               '302960070', '302962032', '303030062', '303032226', '303100249', '303172116', 
                               '303310278', '303312229', '303312653']            
        self.noGameData2011 = ['312462633', '312532006', '312600235', '312602439', 
                               '312670235', '312672653', '313160202', '313160235', '313302348']        
        self.noGameData2012 = ['322430328', '322450154', '322450167', '322520036', '322592572',
                               '322592638', '322662655', '322730113', '322732459', '322732655',
                               '322870195', '322872655', '323152006', '323220113']
        self.noGameData2013 = ['333580204']
        self.noGameData2014 = ['400548012', '400548062', '400548068', '400548080', '400548081',
                               '400548095', '400548125', '400548227', '400548409', '400547715',
                               '400547809', '400547919', '400548223', '400548269', '400548416']
        self.noGameData2015 = ['400787481', '400763646', '400763654', '400787345',
                               '400787363', '400787107', '400787357']
        self.noGameData2016 = ['400868914', '400868922', '400868930', '400868960', '400869143',
                               '400869274', '400869306', '400869182', '400869229', '400869241',
                               '400869370', '400869569', '400869156', '400869353', '400869383',
                               '400869390', '400869539', '400869819', '400869828', '400869842']
        self.noGameData2017 = ['400941794', '400944828', '400935239', '400944873', '400944860']
        self.noGameData2018 = []
        
        self.noGameData  = self.noGameData2003 + self.noGameData2004 + self.noGameData2005 + self.noGameData2006 + self.noGameData2007 + self.noGameData2008 + self.noGameData2009 
        self.noGameData += self.noGameData2010 + self.noGameData2011 + self.noGameData2012 + self.noGameData2013 + self.noGameData2014 + self.noGameData2015 + self.noGameData2016 
        self.noGameData += self.noGameData2017 + self.noGameData2018
                
        
        subdir    = "season"
        outputdir = mkSubDir(self.getSaveDir(), subdir)
        self.seasonDir = outputdir
        
        subdir    = "statistics"
        outputdir = mkSubDir(self.getSaveDir(), subdir)
        self.statisticsDir = outputdir
        
        subdir    = "results"
        outputdir = mkSubDir(self.getSaveDir(), subdir)
        self.resultsDir = outputdir
        
        subdir    = "games"
        outputdir = mkSubDir(self.getSaveDir(), subdir)
        self.gamesDir = outputdir
        
        
        subdir    = "season"
        outputdir = mkSubDir(self.getResultsDir(), subdir)
        self.seasonResultsDir = outputdir
        
        subdir    = "statistics"
        outputdir = mkSubDir(self.getResultsDir(), subdir)
        self.statisticsResultsDir = outputdir
        
        subdir    = "games"
        outputdir = mkSubDir(self.getResultsDir(), subdir)
        self.gamesResultsDir = outputdir
        
    def getSeasonDir(self):
        return self.seasonDir
    
    def getStatisticsDir(self):
        return self.statisticsDir
        
    def getGamesDir(self):
        return self.gamesDir
        
    def getResultsDir(self):
        return self.resultsDir
        
    def getSeasonResultsDir(self):
        return self.seasonResultsDir
        
    def getStatisticsResultsDir(self):
        return self.statisticsResultsDir
        
    def getGamesResultsDir(self):
        return self.gamesResultsDir
        
        
    def getYearlySeasonDir(self, year):
        outputdir = mkSubDir(self.getSeasonDir(), str(year))
        return outputdir
        
        
    def getYearlyStatisticsDir(self, year):
        outputdir = mkSubDir(self.getStatisticsDir(), str(year))
        return outputdir
        
        
    def getYearlyGamesDir(self, year):
        outputdir = mkSubDir(self.getGamesDir(), str(year))
        return outputdir
        
        
    
    ############################################################################################################
    # Team Standings + Games
    ############################################################################################################
    def downloadTeamStandingsByYear(self, year, debug=False):
        baseurl  = self.getBase()
        suburl   = "college-football/standings/_/season"
        url      = join(baseurl, suburl, str(year))
        
        savename  = setFile(self.getSeasonDir(), str(year)+".p")
        if isFile(savename):
            return
        
        if debug:
            print("Downloading {0}".format(url))        
        getWebData(base=url, savename=savename, useSafari=False)
        sleep(10+2*random())


    def downloadTeamStandings(self, startYear=2003, endYear=2018, debug=False):
        for year in range(startYear, endYear+1):
            self.downloadTeamStandingsByYear(year, debug)
        
        
    def downloadTeamDataByYear(self, idval, name, year, debug=False):
        baseurl  = self.getBase()
        suburl   = "college-football/team/schedule/_/id/{0}/season".format(idval)
        url      = join(baseurl, suburl, str(year))
        
        outputdir = self.getYearlySeasonDir(year)
        savename  = setFile(outputdir, "{0}-{1}.p".format(name, year))
        if isFile(savename):
            return
        
        if debug:
            print("Downloading {0} to {1}".format(url, savename))
        getWebData(base=url, savename=savename, useSafari=False)
        sleep(15+2*random())
            
            
    def parseAndDownloadTeamYearlyStandings(self):
        files = findExt(self.getSeasonDir(), ext=".p", debug=False)
        for ifile in files:
            year     = getBaseFilename(ifile)
            htmldata = getFile(ifile)
            bsdata   = getHTML(htmldata)
            
            idVals = {}
            links  = bsdata.findAll("a")
            for link in links:
                attrs = link.attrs
                if attrs.get("data-clubhouse-uid") is not None:
                    href  = attrs['href']
                    name  = getBasename(href)
                    idval = getBasename(getDirname(href))
                    
                    if idVals.get(idval) is not None:
                        if idVals[idval] != name:
                            raise ValueError("Error in ID for this year!")
                    idVals[idval] = name

            for idVal,name in idVals.items():
                self.downloadTeamDataByYear(idVal, name, season=str(year), debug=True)
    #http://www.espn.com/college-football/team/schedule/_/id/201/season/2005"
            
            
    def parseTeamYearlyStandings(self, startYear=2003, endYear=2018, debug=False, verydebug=False):
        for year in range(startYear, endYear+1):
            seasonDir = self.getYearlySeasonDir(year)
            files = findExt(seasonDir, ext=".p", debug=False)
            
            seasonData = season(year)
            
            for ifile in files:
                nameyear = getBaseFilename(ifile)
                htmldata = getFile(ifile)
                bsdata   = getHTML(htmldata)
                teamName = nameyear.replace("-{0}".format(year), "")
                
                
                metadata = bsdata.find("meta", {"property": "og:url"})
                if metadata is None:
                    raise ValueError("Could not find basic team meta data for this file! {0}".format(ifile))
                    
                try:
                    content = metadata.attrs['content']
                    year    = getBasename(content)
                    teamID  = getBasename(getDirname(getDirname(content)))
                except:
                    raise ValueError("Could not get team year and ID from meta data: {0}".format(metadata))
                    
                if verydebug:
                    print(year,'\t',teamID,'\t',ifile)
                
                
                ## Create Team Object
                teamData = team(year=year, teamName=teamName, teamMascot=None, teamID=teamID)
                
                tables = bsdata.findAll("table", {"class": "Table2__table"})
                if verydebug:
                    print("\tFound {0} game tables".format(len(tables)))
                for it,table in enumerate(tables):
                    trs = table.findAll("tr")
                    
                    headers = trs[1]
                    headers = [x.text for x in headers.findAll("td") if x is not None]
                    
                    gameRows = trs[2:]
                    totalGames = len(gameRows)
                    
                    if verydebug:
                        print("\tFound {0} potential games".format(totalGames))
                    
                    for ig,tr in enumerate(gameRows):
                        tds = tr.findAll("td")
                        gameData = dict(zip(headers, tds))
                        extra    = {"OT": False, "Bowl": False}
                        
                        
                        ## Get the Date
                        try:
                            date = gameData["Date"]
                        except:
                            print(ifile)
                            raise ValueError("No date for this game! {0}".format(gameData))                            
                        date = date.text
                        
                        ## Only Keep Games With Regular Dates
                        try:
                            dateval = "{0} {1}".format(date.split(", ")[-1], year)
                            date    = getDateTime(dateval)
                        except:
                            date    = None
                        
                        if date is None:
                            continue
                        
                        ## Check for January Games (in the following year)
                        if date.month == 1:
                            date = addMonths(date, 12)
                            
                        
                        ## Get the Opponent
                        try:
                            opponent = gameData["Opponent"]
                        except:
                            raise ValueError("No opponent for this game! {0}".format(game))   
                            
                        try:
                            oppolink = opponent.find("a")
                            oppohref = oppolink.attrs['href']
                            opponame = getBasename(oppohref)
                            oppoID   = getBasename(getDirname(oppohref))
                        except:
                            opponame = opponent.text
                            oppoID   = 0
                            #raise ValueError("Could not find href in link! {0}".format(opponent))


                        
                        try:
                            gamespan = opponent.find("span", {"class": "pr2"})
                            gametype = gamespan.text
                        except:
                            raise ValueError("Could not find game type from {0}".format(opponent))
                        
                        if gametype == "vs":
                            location = teamID
                        elif gametype == "@":
                            location = oppoID
                        else:
                            raise ValueError("Location --> {0}".format(gametype))
                            
                            
                        if verydebug:
                            print("\t{0}/{1}\t{2}\t{3: <4}{4: <50}".format(ig, totalGames, printDateTime(date), gametype, opponame), end="\t")


                        
                        ## Get the Result
                        try:
                            result = gameData["Result"]
                        except:
                            raise ValueError("No result for this game! {0}".format(game))
                            
                        spans = result.findAll("span")
                        if len(spans) == 0:
                            continue
                        if len(spans) != 2:
                            raise ValueError("There are {0} spans in this row!: {1}".format(len(spans), result))
                        outcome = spans[0].text.strip()
                        score   = spans[1].text.strip()
                        
                        if score.endswith("OT"):
                            extra = {"OT": True}
                            score = score[:-3].strip()
                            
                        try:
                            scores  = [int(x) for x in score.split('-')]
                        except:
                            raise ValueError("Could not create integer scores from {0}".format(spans))

                        if outcome == 'W':                            
                            teamScore  = scores[0]
                            oppoScore  = scores[1]
                            teamResult = "W"
                            oppoResult = "L"
                        elif outcome == "L":
                            teamScore = scores[1]
                            oppoScore = scores[0]
                            teamResult = "L"
                            oppoResult = "W"
                        elif outcome == "T":
                            teamScore = scores[0]
                            oppoScore = scores[1]
                            teamResult = "T"
                            oppoResult = "T"
                        else:
                            raise ValueError("Did not recognize game outcome {0}".format(outcome))


                        ## Get the Game
                        try:
                            gamelink = result.find("a")
                            gamehref = gamelink.attrs['href']
                        except:
                            raise ValueError("Could not find href in link! {0}".format(result))

                            
                        if verydebug:
                            print("{0}  {1}".format(teamResult, "-".join(str(x) for x in [teamScore,oppoScore])))
                            
                            
                        ## Create game object
                        gameData = game(gameID=gameID, date=date, teamA=teamID, teamB=oppoID,
                                        teamAResult=teamResult, teamBResult=oppoResult,
                                        teamAScore=teamScore, teamBScore=oppoScore, location=location)
                        
                        
                        ## Append game to team data
                        teamData.addGame(gameData)
                        

                ## Show Summary
                teamData.setStatistics()
                if debug:
                    teamData.summary()
                    if teamData.ngames == 0:
                        removeFile(ifile, debug=True)
                        
                seasonData.addTeam(teamData)
                
            #http://www.espn.com/college-football/team/schedule/_/id/201/season/2005"

            savename = setFile(self.getSeasonResultsDir(), "{0}.p".format(year))            
            saveFile(idata=seasonData, ifile=savename, debug=True)
                        
         
    ############################################################################################################
    # Team Games
    ############################################################################################################   
    def downloadGameDataByID(self, gameID, year, test=False, debug=False):        
        gamesDir   = self.getYearlyGamesDir(year)
        url="http://www.espn.com/college-football/playbyplay?gameId={0}".format(gameID)
        savename = setFile(gamesDir, "{0}.p".format(gameID))

        if isFile(savename):
            from os.path import getsize                    
            size = round(getsize(savename)/1e3)
            if size < 1:
                removeFile(savename, debug=True)

        if test:
            print("Downloading {0} to {1}".format(url,savename))
            return
        getWebData(base=url, savename=savename, dtime=6, useSafari=True, debug=True)
        sleep(6)
            
            
    def downloadGameData(self, debug=False, verydebug=False):
        resultsDir = self.getSeasonResultsDir()
        files = findExt(resultsDir, ext=".p", debug=False)

        gameType = "playbyplay"
        print("Sleeping for 5 seconds...")
        sleep(5)

        
        for ifile in files:
            seasonData = getFile(ifile)
            year       = seasonData.getYear()
            if year not in [2013,2014,2015]:
                continue
            gamesDir   = self.getYearlyGamesDir(year)
            
            teams = seasonData.teams
            for teamID,teamData in teams.items():
                teamGames = teamData.games
                for gameData in teamGames:
                    gameResult = gameData["Result"]
                    gameObject = gameData["Game"]
                    gameID     = gameObject.gameID
                    
                    if False:
                        prevLocation = "/Volumes/Seagate/Football/Games/Plays/{0}.html".format(gameID)
                        if isFile(prevLocation):
                            savename = setFile(gamesDir, "{0}.p".format(gameID))
                            if not isFile(savename) or True:
                                data = open(prevLocation, "rb").read()
                                saveFile(idata=data, ifile=savename, debug=True)
                                continue
                        continue

                    self.downloadGameDataByID(gameID, year, debug)
                        
                        
            
            
    def parseGameData(self, startYear=2003, endYear=2018, debug=False, verydebug=False):
        noData = {}
        for year in range(startYear, endYear+1):
            
            yearData = {}
            
            gamesDir = self.getYearlyGamesDir(year)        
            files    = findExt(gamesDir, ext=".p", debug=False)
            
            
            noData[year] = []
            for i,ifile in enumerate(files):
                gameID   = getBaseFilename(ifile)
                
                if gameID in self.noGameData:
                    continue
                
                htmldata = getFile(ifile)
                bsdata   = getHTML(htmldata)
                #print(bsdata)
                
                
                #verydebug=True
                #if gameID not in ['400603866']:
                #    continue
                
                teamData  = bsdata.findAll("div", {"class": "team-container"})
                
                longNames = [x.find("span", {"class": "long-name"}) for x in teamData]
                longNames = [x.text for x in longNames if x is not None]
                
                shortNames = [x.find("span", {"class": "short-name"}) for x in teamData]
                shortNames = [x.text for x in shortNames if x is not None]
                
                teamAbbrevs = [x.find("span", {"class": "abbrev"}) for x in teamData]
                teamNames   = [x.attrs for x in teamAbbrevs if x is not None]
                teamNames   = [x['title'] for x in teamNames]
                teamAbbrevs = [x.text for x in teamAbbrevs]
                
                teamIDs = [x.find("img", {"class": "team-logo"}) for x in teamData]
                teamIDs = [x.attrs for x in teamIDs if x is not None]
                teamIDs = [x['src'] for x in teamIDs]
                teamIDs = [re.search(r"(\d+).png", x) for x in teamIDs]
                teamIDs = [x.groups()[0] for x in teamIDs]

                awayTeam = {"Name": longNames[0], "Mascot": shortNames[0], "Abbrev": teamAbbrevs[0], "ID": teamIDs[0]}
                homeTeam = {"Name": longNames[1], "Mascot": shortNames[1], "Abbrev": teamAbbrevs[1], "ID": teamIDs[1]}
                
                    
                
                metadata = bsdata.find("meta", {"property": "og:title"})
                title    = None
                if metadata is not None:
                    title = metadata.attrs['content']
                    if verydebug:
                        print("==> {0}".format(title))
                
                ## Possesions
                posData = bsdata.find("ul", {"class": "css-accordion"})
                if posData is None:
                    posData = bsdata.find("article", {"class": "play-by-play"})
                if posData is None:
                    noData[year].append(gameID)
                    if verydebug:
                        print("Could not find possession data! {0}".format(gameID))
                    continue
                    #print(bsdata)
                    #1/0
                    #removeFile(ifile, debug)
                    #continue
                
                
                gameData = {"Teams": {"Away": awayTeam, "Home": homeTeam}, "Plays": []}

                if i % 10 == 0:
                    print("{0}/{1} with {2} no data games".format(i,len(files),len(noData[year])))
                
                    
                ###################
                ## Get Full Drive Data
                ###################

                drives = posData.findAll("li", {"class": "accordion-item"})
                if verydebug:
                    print("Drives {0}".format(len(drives)))

                for idr,drive in enumerate(drives):                                            

                    ## Get Drive Summary
                    headlines = [x.text.strip() for x in drive.findAll("span", {"class": "headline"})]
                    if verydebug:
                        print("Headlines {0}".format(len(headlines)))


                    ## Get Drive Details
                    details = [x.text.strip() for x in drive.findAll("span", {"class": "drive-details"})]
                    if verydebug:
                        print("Details {0}".format(len(details)))


                    ## Get Home Score
                    homescores = drive.findAll("span", {"class": "home"})
                    homescores = [x.find("span", {"class": "team-score"}) for x in homescores]
                    homescores = [x.text for x in homescores if x is not None]
                    if verydebug:
                        print("Home Scores {0}".format(len(homescores)))


                    ## Get Away Score
                    awayscores = drive.findAll("span", {"class": "away"})
                    awayscores = [x.find("span", {"class": "team-score"}) for x in awayscores]
                    awayscores = [x.text for x in awayscores if x is not None]
                    if verydebug:
                        print("Away Scores {0}".format(len(awayscores)))


                    ## Get Possession
                    possessions = drive.findAll("span", {"class": "home-logo"})
                    possessions = [x.find("img", {"class": "team-logo"}) for x in possessions]
                    possessions = [x.attrs['src'] for x in possessions if x is not None]
                    possessions = [x.split('&')[0] for x in possessions]
                    possessions = [getBaseFilename(x) for x in possessions]
                    if verydebug:
                        print("Possessions {0}".format(len(possessions)))


                    ## Check for valid headline (parsed correctly?)
                    if len(headlines) == 0:
                        continue
                        
                    validFGs    = ["Missed FG", "Field Goal", "FIELD GOAL", "MISSED FG", "Made FG",
                                   "Field Goal Good", "Field Goal Missed", "Blocked FG"]
                    validTDs    = ["Touchdown", "TOUCHDOWN", "END OF HALF Touchdown", "Downs Touchdown",                                  
                                   "Missed FG Touchdown", "End of Half Touchdown", "End of Game Touchdown", 
                                   "PUNT Touchdown", "FUMBLE Touchdown", "INTERCEPTION Touchdown",
                                   "FIELD GOAL Touchdown", "MISSED FG Touchdown", "Rushing Touchdown", "Passing Touchdown",
                                  "Kickoff Return Touchdown", "Interception Return Touch", "Turnover on Downs Touchdown",
                                  "Field Goal Missed Touchdown", "Field Goal Touchdown", "Rushing Touchdown Touchdown",
                                  "Field Goal Good Touchdown", "Passing Touchdown Touchdown",
                                   "Fumble Return Touchdown Touchdown", "Rushing TD", "Passing TD",
                                   "Blocked Punt TD", "Punt Return TD", "Fumble Ret. TD",
                                   "Interception TD", "Fumble TD", "Rushing TD Touchdown",
                                   "Blocked Punt TD Touchdown", "Blocked FG (TD)",
                                   "Punt Return TD Touchdown", "Kick Return TD",
                                   "Kickoff Return Touchdown Touchdown",
                                   "Missed FG (TD) Touchdown", "Blocked FG (TD) Touchdown",
                                   "Punt Return Touchdown Touchdown", "Interception Return Touch Touchdown"]
                    validEnds   = ["End of Half", "End of Game", "END OF HALF", "END OF GAME", "End of 4th Quarter"]
                    validTOs    = ["Fumble", "Interception", "FUMBLE", "INTERCEPTION", "Kickoff", "KICKOFF",
                                  "Blocked Punt"]
                    validTOPnts = ["Interception Touchdown", "Safety", "Punt Touchdown", "Fumble Touchdown",
                                   "Punt Return Touchdown", "Fumble Return Touchdown", "SAFETY"]
                    validDowns  = ["Punt", "Downs", "PUNT", "Possession (For OT Drives)", "DOWNS",
                                   "Possession (For OT Drives) Touchdown", "Turnover on Downs",
                                  "Poss. on downs", "Penalty"]
                    validPlay   = ["Rush", "Pass", "Sack", "Timeout", "Incomplete", "Pass Complete"]
                    valid2PT    = ["2PT Pass failed", "Missed PAT Return"]
                    validOdds   = ["on-side kick"]
                    validHeadlines  = validFGs + validTDs + validEnds + validTOs + validTOPnts + validDowns + validPlay + valid2PT
                    isValidHeadline = sum([x in validHeadlines for x in headlines])
                    if headlines[0] == '':
                        continue
                    if isValidHeadline == 0 and idr < len(drives) - 1:
                        print(idr,'/',len(drives))
                        print(title)
                        print(ifile)
                        #print(bsdata)
                        raise ValueError("No valid headline in {0}".format(headlines))
                        print("No valid headline in {0}".format(headlines))
                        continue


                    ## Analyze Play-by-Play
                    try:
                        driveList = drive.find("ul", {"class": "drive-list"})                        
                        plays = driveList.findAll("li")
                    except:
                        raise ValueError("Could not find drive list in drive {0}".format(drive))

                    driveData = []
                    for ip,play in enumerate(plays):

                        ## Check for Starting Position
                        startPos = play.find("h3")
                        if startPos is None:
                            raise ValueError("Could not find Starting Position in Play! {0}".format(play))
                        startData = startPos.text.strip()


                        ## Check for Play Text
                        span = play.find("span", {"class": "post-play"})
                        if span is None:
                            raise ValueError("Could not find post play data! {0}".format(play))
                        playData = span.text.strip()


                        driveData.append({"Play": ip, "Start": startData, "Data": playData})

                        #print(idr,'\t',ip,'\t',startData,'\t',playData)


                    ## Save Drive Data
                    gameData["Plays"].append({"Drive": len(gameData), "Headline": headlines, "Detail": details, 
                                              "HomeScore": homescores, "AwayScore": awayscores,
                                              "Possession": possessions, "Data": driveData})



                    if verydebug:
                        print(idr,'\t',headlines)
                        print(idr,'\t',details)
                        print(idr,'\t',homescores)
                        print(idr,'\t',awayscores)
                        print(idr,'\t',possessions)
                        print("")

                if verydebug:
                    print("Found {0} drives for gameID {1}".format(len(gameData), gameID))
                yearData[gameID] = gameData
                
            print("Parsed {0}/{1} games in {2}".format(len(yearData), len(files), year))
            savename = setFile(self.getGamesResultsDir(), "{0}-games.p".format(year))
            saveFile(idata=yearData, ifile=savename, debug=True)
            
        return noData

        

            
        
        
    
    ############################################################################################################
    # Team Statistics
    ############################################################################################################
    def downloadTeamStatisticsDataByYear(self, idval, name, year, debug=False):
        baseurl  = self.getBase()
        suburl   = "college-football/team/stats/_/id/{0}/season".format(idval)
        url      = join(baseurl, suburl, str(year))
        
        outputdir = self.getYearlyStatisticsDir(year)
        savename  = setFile(outputdir, "{0}-{1}.p".format(name, year))
        if isFile(savename):
            return
        
        if debug:
            print("Downloading {0} to {1}".format(url, savename))
        getWebData(base=url, savename=savename, useSafari=False)
        sleep(15+2*random())        
        
        
    def downloadTeamStatisticsData(self, debug=False):
        resultsDir = self.getSeasonResultsDir()
        files = findExt(resultsDir, ext=".p", debug=False)

        sleep(3)
        
        for ifile in files:
            seasonData = getFile(ifile)
            year       = seasonData.getYear()
            gamesDir   = self.getYearlyGamesDir(year)
            
            if year < 2012:
                continue
            
            teams = seasonData.teams
            for teamID,teamData in teams.items():
                name = teamData.teamName
                self.downloadTeamStatisticsDataByYear(teamID, name, year, debug)
                

    def parseTeamStatisticsData(self, startYear=2014, endYear=2018, debug=False, verydebug=False):
        for year in range(startYear, endYear+1):
            
            yearData = {}
            
            statsDir = self.getYearlyStatisticsDir(year)        
            files    = findExt(statsDir, ext=".p", debug=False)
            
            
            for i,ifile in enumerate(files):
                teamStatistics = {}

                print(ifile)
                htmldata = getFile(ifile)
                bsdata   = getHTML(htmldata)
                
                teamName = bsdata.find("link", {"data-react-helmet": "true", "rel": "canonical"})
                if teamName is None:
                    raise ValueError("Could not get team ID from name!")
                try:
                    href = teamName.attrs['href']
                    teamID  = getBasename(getDirname(getDirname(href)))
                except:
                    raise ValueError("Could not get team ID from {0}".format(teamName))

                
                divs       = bsdata.findAll("div", {"class": "Table2__Title"})
                tableNames = [x.text for x in divs]
                
                tables = bsdata.findAll("table", {"class": "Table2__table__wrapper"})
                
                ## Skip the team leaders table
                tableNames = tableNames[1:]
                #tables     = tables[1:]
                if len(tables) != len(tableNames):
                    for it,table in enumerate(tables):
                        ths     = table.findAll("th")
                        headers = [x.text for x in ths]
                        print(it,headers)
                        
                    raise ValueError("There are {0} tables and {1} names".format(len(tables), tableNames))
                #print("  Found {0} tables and {1} names".format(len(tables), len(tableNames)))
                
                    
                    
                tableData = dict(zip(tableNames, tables))                
                for tableName, table in tableData.items():
                    ths     = table.findAll("th")
                    headers = [x.text for x in ths]
                    
                    trs     = table.findAll("tr")[2:]
                    
                    players = {}
                    iData   = -1
                    for tr in trs:
                        linedata = [x for x in tr.strings]
                        
                        ## Get player first
                        if len(linedata) == 3:
                            try:
                                name     = linedata[0]
                                position = linedata[2]
                            except:
                                raise ValueError("Could not parse line data: {0}".format(linedata))
                                
                            key = "$".join([name,position])
                            players[key] = None
                        elif len(linedata) == 1:
                            players["TOTAL$ALL"] = None
                            playerNames = list(players.keys())
                        elif len(linedata) == len(headers) - 1:
                            if iData == -1:
                                header = linedata
                                iData += 1
                                continue
                            else:
                                try:
                                    playerData = dict(zip(header, linedata))
                                except:
                                    raise ValueError("Could not combine header [{0}] with data [{1}]".format(header, linedata))
                                    
                            try:
                                players[playerNames[iData]] = playerData
                            except:
                                raise ValueError("Could not set data for [{0}] with data: {1}".format(iData,playerData))
                            #print(iData,'\t',playerNames[iData],'\t',playerData)
                            iData += 1
                            
                    #print(tableName,'-->',players)
                    teamStatistics[tableName] = players
                
                yearData[teamID] = teamStatistics
                
            print("Parsed {0}/{1} games in {2}".format(len(yearData), len(files), year))
            savename = setFile(self.getStatisticsResultsDir(), "{0}-stats.json".format(year))
            saveFile(idata=yearData, ifile=savename, debug=True)
            
            
    def findMissingStatistics(self, startYear=2013, endYear=2018, debug=False, verydebug=False):
        statsToGet = {}
        for year in range(startYear, endYear+1):
            statsToGet[year] = {}
            seasonFilename = setFile(self.getSeasonResultsDir(), "{0}.p".format(year))
            seasonData     = getFile(seasonFilename)
            
            statsFilename = setFile(self.getStatisticsResultsDir(), "{0}-stats.json".format(year))
            statsData     = getFile(statsFilename)
            
            for teamID,teamData in seasonData.teams.items():                
                games = [x["Game"] for x in teamData.games]
                
                for game in games:
                    teamA = game.teamA
                    teamB = game.teamB
                    
                if statsData.get(teamA) is None:                  
                    try:
                        statsToGet[year][teamA] = seasonData.teams[teamA].teamName
                        print("Could not find {0} in {1} stats".format(teamA, year))
                    except:
                        pass
                        #statsToGet[year][teamA] = teamA
                        
                if statsData.get(teamB) is None:
                    try:
                        statsToGet[year][teamB] = seasonData.teams[teamB].teamName
                        print("Could not find {0} in {1} stats".format(teamB, year))
                    except:
                        pass
                        #statsToGet[year][teamB] = teamB

            #statsToGet[year] = list(statsToGet[year].keys())
        return statsToGet

# %%
hist = historical()

# %%
#hist.parseTeamStatisticsData(startYear=2018)

# %%
#statsToGet = hist.findMissingStatistics()
#statsToGet

# %%
for year,teams in statsToGet.items():
    for teamID,name in teams.items():
        print(year,teamID,name)
        hist.downloadTeamStatisticsDataByYear(teamID, name, year, debug=True)

# %%
hist.downloadTeamStatisticsData()
# Out:
#   --> This file is 65.5kB.
# /Volumes/Blue/Football/statistics/2012/louisiana-monroe-warhawks-2012.p size -> 66 kB
#   --> This file is 65.1kB.
# /Volumes/Blue/Football/statistics/2012/louisiana-ragin-cajuns-2012.p size -> 65 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2012/louisiana-tech-bulldogs-2012.p size -> 65 kB
#   --> This file is 64.3kB.
# /Volumes/Blue/Football/statistics/2012/louisville-cardinals-2012.p size -> 64 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/lsu-tigers-2012.p size -> 65 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2012/marshall-thundering-herd-2012.p size -> 65 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2012/maryland-terrapins-2012.p size -> 65 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2012/memphis-tigers-2012.p size -> 64 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2012/miami-hurricanes-2012.p size -> 65 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2012/miami-oh-redhawks-2012.p size -> 64 kB
#   --> This file is 63.9kB.
# /Volumes/Blue/Football/statistics/2012/michigan-state-spartans-2012.p size -> 64 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2012/michigan-wolverines-2012.p size -> 65 kB
#   --> This file is 65.1kB.
# /Volumes/Blue/Football/statistics/2012/middle-tennessee-blue-raiders-2012.p size -> 65 kB
#   --> This file is 66.1kB.
# /Volumes/Blue/Football/statistics/2012/minnesota-golden-gophers-2012.p size -> 66 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2012/mississippi-state-bulldogs-2012.p size -> 65 kB
#   --> This file is 64.2kB.
# /Volumes/Blue/Football/statistics/2012/missouri-tigers-2012.p size -> 64 kB
#   --> This file is 65.3kB.
# /Volumes/Blue/Football/statistics/2012/navy-midshipmen-2012.p size -> 65 kB
#   --> This file is 64.0kB.
# /Volumes/Blue/Football/statistics/2012/nc-state-wolfpack-2012.p size -> 64 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2012/nebraska-cornhuskers-2012.p size -> 65 kB
#   --> This file is 63.3kB.
# /Volumes/Blue/Football/statistics/2012/nevada-wolf-pack-2012.p size -> 63 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2012/new-mexico-lobos-2012.p size -> 65 kB
#   --> This file is 63.0kB.
# /Volumes/Blue/Football/statistics/2012/new-mexico-state-aggies-2012.p size -> 63 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2012/north-carolina-tar-heels-2012.p size -> 65 kB
#   --> This file is 62.7kB.
# /Volumes/Blue/Football/statistics/2012/north-texas-mean-green-2012.p size -> 63 kB
#   --> This file is 65.9kB.
# /Volumes/Blue/Football/statistics/2012/northern-illinois-huskies-2012.p size -> 66 kB
#   --> This file is 65.5kB.
# /Volumes/Blue/Football/statistics/2012/northwestern-wildcats-2012.p size -> 65 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2012/notre-dame-fighting-irish-2012.p size -> 64 kB
#   --> This file is 65.1kB.
# /Volumes/Blue/Football/statistics/2012/ohio-bobcats-2012.p size -> 65 kB
#   --> This file is 64.1kB.
# /Volumes/Blue/Football/statistics/2012/ohio-state-buckeyes-2012.p size -> 64 kB
#   --> This file is 63.6kB.
# /Volumes/Blue/Football/statistics/2012/oklahoma-sooners-2012.p size -> 64 kB
#   --> This file is 66.1kB.
# /Volumes/Blue/Football/statistics/2012/oklahoma-state-cowboys-2012.p size -> 66 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2012/ole-miss-rebels-2012.p size -> 65 kB
#   --> This file is 67.1kB.
# /Volumes/Blue/Football/statistics/2012/oregon-ducks-2012.p size -> 67 kB
#   --> This file is 66.4kB.
# /Volumes/Blue/Football/statistics/2012/oregon-state-beavers-2012.p size -> 66 kB
#   --> This file is 63.4kB.
# /Volumes/Blue/Football/statistics/2012/penn-state-nittany-lions-2012.p size -> 63 kB
#   --> This file is 63.6kB.
# /Volumes/Blue/Football/statistics/2012/pittsburgh-panthers-2012.p size -> 64 kB
#   --> This file is 66.6kB.
# /Volumes/Blue/Football/statistics/2012/purdue-boilermakers-2012.p size -> 67 kB
#   --> This file is 64.4kB.
# /Volumes/Blue/Football/statistics/2012/rice-owls-2012.p size -> 64 kB
#   --> This file is 63.5kB.
# /Volumes/Blue/Football/statistics/2012/rutgers-scarlet-knights-2012.p size -> 63 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2012/san-diego-state-aztecs-2012.p size -> 64 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/san-jose-state-spartans-2012.p size -> 65 kB
#   --> This file is 63.6kB.
# /Volumes/Blue/Football/statistics/2012/smu-mustangs-2012.p size -> 64 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2012/south-alabama-jaguars-2012.p size -> 64 kB
#   --> This file is 65.5kB.
# /Volumes/Blue/Football/statistics/2012/south-carolina-gamecocks-2012.p size -> 65 kB
#   --> This file is 65.3kB.
# /Volumes/Blue/Football/statistics/2012/south-florida-bulls-2012.p size -> 65 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/southern-mississippi-golden-eagles-2012.p size -> 65 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/stanford-cardinal-2012.p size -> 65 kB
#   --> This file is 62.4kB.
# /Volumes/Blue/Football/statistics/2012/syracuse-orange-2012.p size -> 62 kB
#   --> This file is 64.3kB.
# /Volumes/Blue/Football/statistics/2012/tcu-horned-frogs-2012.p size -> 64 kB
#   --> This file is 63.5kB.
# /Volumes/Blue/Football/statistics/2012/temple-owls-2012.p size -> 63 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2012/tennessee-volunteers-2012.p size -> 65 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2012/texas-am-aggies-2012.p size -> 65 kB
#   --> This file is 65.9kB.
# /Volumes/Blue/Football/statistics/2012/texas-longhorns-2012.p size -> 66 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2012/texas-state-bobcats-2012.p size -> 65 kB
#   --> This file is 65.3kB.
# /Volumes/Blue/Football/statistics/2012/texas-tech-red-raiders-2012.p size -> 65 kB
#   --> This file is 63.4kB.
# /Volumes/Blue/Football/statistics/2012/toledo-rockets-2012.p size -> 63 kB
#   --> This file is 63.3kB.
# /Volumes/Blue/Football/statistics/2012/troy-trojans-2012.p size -> 63 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2012/tulane-green-wave-2012.p size -> 65 kB
#   --> This file is 63.2kB.
# /Volumes/Blue/Football/statistics/2012/tulsa-golden-hurricane-2012.p size -> 63 kB
#   --> This file is 63.0kB.
# /Volumes/Blue/Football/statistics/2012/uab-blazers-2012.p size -> 63 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2012/ucf-knights-2012.p size -> 65 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2012/ucla-bruins-2012.p size -> 65 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/umass-minutemen-2012.p size -> 65 kB
#   --> This file is 63.2kB.
# /Volumes/Blue/Football/statistics/2012/unlv-rebels-2012.p size -> 63 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2012/usc-trojans-2012.p size -> 65 kB
#   --> This file is 65.5kB.
# /Volumes/Blue/Football/statistics/2012/ut-san-antonio-roadrunners-2012.p size -> 66 kB
#   --> This file is 66.5kB.
# /Volumes/Blue/Football/statistics/2012/utah-state-aggies-2012.p size -> 66 kB
#   --> This file is 66.2kB.
# /Volumes/Blue/Football/statistics/2012/utah-utes-2012.p size -> 66 kB
#   --> This file is 65.6kB.
# /Volumes/Blue/Football/statistics/2012/utep-miners-2012.p size -> 66 kB
#   --> This file is 63.9kB.
# /Volumes/Blue/Football/statistics/2012/vanderbilt-commodores-2012.p size -> 64 kB
#   --> This file is 64.2kB.
# /Volumes/Blue/Football/statistics/2012/virginia-cavaliers-2012.p size -> 64 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2012/virginia-tech-hokies-2012.p size -> 65 kB
#   --> This file is 64.0kB.
# /Volumes/Blue/Football/statistics/2012/wake-forest-demon-deacons-2012.p size -> 64 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2012/washington-huskies-2012.p size -> 64 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2012/washington-state-cougars-2012.p size -> 64 kB
#   --> This file is 64.4kB.
# /Volumes/Blue/Football/statistics/2012/west-virginia-mountaineers-2012.p size -> 64 kB
#   --> This file is 65.1kB.
# /Volumes/Blue/Football/statistics/2012/western-kentucky-hilltoppers-2012.p size -> 65 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2012/western-michigan-broncos-2012.p size -> 65 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2012/wisconsin-badgers-2012.p size -> 65 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2012/wyoming-cowboys-2012.p size -> 64 kB
#   --> This file is 65.1kB.
# /Volumes/Blue/Football/statistics/2013/akron-zips-2013.p size -> 65 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2013/alabama-crimson-tide-2013.p size -> 65 kB
#   --> This file is 50.4kB.
# /Volumes/Blue/Football/statistics/2013/arizona-state-sun-devils-2013.p size -> 50 kB
#   --> This file is 63.3kB.
# /Volumes/Blue/Football/statistics/2013/arizona-wildcats-2013.p size -> 63 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2013/arkansas-razorbacks-2013.p size -> 64 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2013/arkansas-state-red-wolves-2013.p size -> 64 kB
#   --> This file is 65.6kB.
# /Volumes/Blue/Football/statistics/2013/army-black-knights-2013.p size -> 66 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/auburn-tigers-2013.p size -> 65 kB
#   --> This file is 63.2kB.
# /Volumes/Blue/Football/statistics/2013/ball-state-cardinals-2013.p size -> 63 kB
#   --> This file is 65.7kB.
# /Volumes/Blue/Football/statistics/2013/baylor-bears-2013.p size -> 66 kB
#   --> This file is 66.2kB.
# /Volumes/Blue/Football/statistics/2013/boise-state-broncos-2013.p size -> 66 kB
#   --> This file is 61.8kB.
# /Volumes/Blue/Football/statistics/2013/boston-college-eagles-2013.p size -> 62 kB
#   --> This file is 64.0kB.
# /Volumes/Blue/Football/statistics/2013/bowling-green-falcons-2013.p size -> 64 kB
#   --> This file is 64.2kB.
# /Volumes/Blue/Football/statistics/2013/buffalo-bulls-2013.p size -> 64 kB
#   --> This file is 65.5kB.
# /Volumes/Blue/Football/statistics/2013/byu-cougars-2013.p size -> 65 kB
#   --> This file is 65.4kB.
# /Volumes/Blue/Football/statistics/2013/california-golden-bears-2013.p size -> 65 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2013/central-michigan-chippewas-2013.p size -> 65 kB
#   --> This file is 66.2kB.
# /Volumes/Blue/Football/statistics/2013/cincinnati-bearcats-2013.p size -> 66 kB
#   --> This file is 66.5kB.
# /Volumes/Blue/Football/statistics/2013/clemson-tigers-2013.p size -> 67 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2013/colorado-buffaloes-2013.p size -> 64 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2013/colorado-state-rams-2013.p size -> 65 kB
#   --> This file is 63.6kB.
# /Volumes/Blue/Football/statistics/2013/connecticut-huskies-2013.p size -> 64 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2013/duke-blue-devils-2013.p size -> 64 kB
#   --> This file is 65.8kB.
# /Volumes/Blue/Football/statistics/2013/east-carolina-pirates-2013.p size -> 66 kB
#   --> This file is 62.9kB.
# /Volumes/Blue/Football/statistics/2013/eastern-michigan-eagles-2013.p size -> 63 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2013/florida-atlantic-owls-2013.p size -> 65 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/florida-gators-2013.p size -> 65 kB
#   --> This file is 64.1kB.
# /Volumes/Blue/Football/statistics/2013/florida-intl-golden-panthers-2013.p size -> 64 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2013/florida-state-seminoles-2013.p size -> 65 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2013/fresno-state-bulldogs-2013.p size -> 64 kB
#   --> This file is 65.8kB.
# /Volumes/Blue/Football/statistics/2013/georgia-bulldogs-2013.p size -> 66 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/georgia-state-panthers-2013.p size -> 65 kB
#   --> This file is 66.7kB.
# /Volumes/Blue/Football/statistics/2013/georgia-tech-yellow-jackets-2013.p size -> 67 kB
#   --> This file is 65.7kB.
# /Volumes/Blue/Football/statistics/2013/hawaii-rainbow-warriors-2013.p size -> 66 kB
#   --> This file is 64.3kB.
# /Volumes/Blue/Football/statistics/2013/houston-cougars-2013.p size -> 64 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2013/idaho-vandals-2013.p size -> 64 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/illinois-fighting-illini-2013.p size -> 65 kB
#   --> This file is 64.2kB.
# /Volumes/Blue/Football/statistics/2013/indiana-hoosiers-2013.p size -> 64 kB
#   --> This file is 63.6kB.
# /Volumes/Blue/Football/statistics/2013/iowa-hawkeyes-2013.p size -> 64 kB
#   --> This file is 65.3kB.
# /Volumes/Blue/Football/statistics/2013/iowa-state-cyclones-2013.p size -> 65 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/kansas-jayhawks-2013.p size -> 65 kB
#   --> This file is 63.3kB.
# /Volumes/Blue/Football/statistics/2013/kansas-state-wildcats-2013.p size -> 63 kB
#   --> This file is 63.3kB.
# /Volumes/Blue/Football/statistics/2013/kent-state-golden-flashes-2013.p size -> 63 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/kentucky-wildcats-2013.p size -> 65 kB
#   --> This file is 63.8kB.
# /Volumes/Blue/Football/statistics/2013/louisiana-monroe-warhawks-2013.p size -> 64 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/louisiana-ragin-cajuns-2013.p size -> 65 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2013/louisiana-tech-bulldogs-2013.p size -> 65 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/louisville-cardinals-2013.p size -> 65 kB
#   --> This file is 63.9kB.
# /Volumes/Blue/Football/statistics/2013/lsu-tigers-2013.p size -> 64 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/marshall-thundering-herd-2013.p size -> 65 kB
#   --> This file is 63.7kB.
# /Volumes/Blue/Football/statistics/2013/maryland-terrapins-2013.p size -> 64 kB
#   --> This file is 63.4kB.
# /Volumes/Blue/Football/statistics/2013/memphis-tigers-2013.p size -> 63 kB
#   --> This file is 65.8kB.
# /Volumes/Blue/Football/statistics/2013/miami-hurricanes-2013.p size -> 66 kB
#   --> This file is 65.0kB.
# /Volumes/Blue/Football/statistics/2013/miami-oh-redhawks-2013.p size -> 65 kB
#   --> This file is 64.8kB.
# /Volumes/Blue/Football/statistics/2013/michigan-state-spartans-2013.p size -> 65 kB
#   --> This file is 64.7kB.
# /Volumes/Blue/Football/statistics/2013/michigan-wolverines-2013.p size -> 65 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/middle-tennessee-blue-raiders-2013.p size -> 65 kB
#   --> This file is 64.6kB.
# /Volumes/Blue/Football/statistics/2013/minnesota-golden-gophers-2013.p size -> 65 kB
#   --> This file is 65.7kB.
# /Volumes/Blue/Football/statistics/2013/mississippi-state-bulldogs-2013.p size -> 66 kB
#   --> This file is 64.0kB.
# /Volumes/Blue/Football/statistics/2013/missouri-tigers-2013.p size -> 64 kB
#   --> This file is 64.4kB.
# /Volumes/Blue/Football/statistics/2013/navy-midshipmen-2013.p size -> 64 kB
#   --> This file is 65.8kB.
# /Volumes/Blue/Football/statistics/2013/nc-state-wolfpack-2013.p size -> 66 kB
#   --> This file is 65.2kB.
# /Volumes/Blue/Football/statistics/2013/nebraska-cornhuskers-2013.p size -> 65 kB
#   --> This file is 63.9kB.
# /Volumes/Blue/Football/statistics/2013/nevada-wolf-pack-2013.p size -> 64 kB
#   --> This file is 64.9kB.
# /Volumes/Blue/Football/statistics/2013/new-mexico-lobos-2013.p size -> 65 kB
#   --> This file is 64.5kB.
# /Volumes/Blue/Football/statistics/2013/new-mexico-state-aggies-2013.p size -> 65 kB
#   --> This file is 65.9kB.
# /Volumes/Blue/Football/statistics/2013/north-carolina-tar-heels-2013.p size -> 66 kB
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-38-fcba9afd786b> in <module>()
# ----> 1 hist.downloadTeamStatisticsData()
#
# <ipython-input-32-1e94f50acafd> in downloadTeamStatisticsData(self, debug)
#     827             for teamID,teamData in teams.items():
#     828                 name = teamData.teamName
# --> 829                 self.downloadTeamStatisticsDataByYear(teamID, name, year, debug)
#     830
#     831
#
# <ipython-input-32-1e94f50acafd> in downloadTeamStatisticsDataByYear(self, idval, name, year, debug)
#     806         if debug:
#     807             print("Downloading {0} to {1}".format(url, savename))
# --> 808         getWebData(base=url, savename=savename, useSafari=False)
#     809         sleep(15+2*random())
#     810
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/utils-0.0.1-py3.6.egg/webUtils.py in getWebData(base, suburl, extra, savename, dtime, useSafari, debug)
#     109         retval = getSafariURL(url, savename, dtime, debug)
#     110     else:
# --> 111         retval = getURL(url, savename, debug)
#     112
#     113     return retval
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/utils-0.0.1-py3.6.egg/webUtils.py in getURL(url, savename, debug)
#      24     if debug:
#      25         print("Downloading {0}".format(url))
# ---> 26     content = urlopen(url).read()
#      27     saveJoblib(content, savename)
#      28     #pickle.dump(content, open(savename, "w"))
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda3/envs/py36/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 504: Gateway Time-out
